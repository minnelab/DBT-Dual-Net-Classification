# %%
import os
import random
from PIL import Image
from torch.utils.data import Dataset
from torchvision import transforms


class CustomContrastiveDataset(Dataset):
    def __init__(self, data_dir,base_transform=None,transform1=None, transform2=None):
        self.data_dir = data_dir
        self.base_transform=base_transform
        self.transform_pos = transform1
        self.transform_neg = transform2
        self.image_paths = self._load_image_paths(data_dir)
        self.patient_data = self._group_images_by_patient()

    def _load_image_paths(self, data_dir):
        return [os.path.join(data_dir, img_name) for img_name in os.listdir(data_dir) if img_name.endswith('.png')]
    
    def _group_images_by_patient(self):
        patient_dict = {}
        for img_path in self.image_paths:
            patient_id = self.get_patient_id(img_path)
            if patient_id not in patient_dict:
                patient_dict[patient_id] = []
            patient_dict[patient_id].append(img_path)
        return patient_dict
    
    def get_patient_id(self, img_name):
        return img_name.split('_')[0]
    
    def get_side_view(self, img_name):
        if 'r' in img_name:
            return 'r' 
        elif 'l' in img_name:
            return 'l'
        return None
    
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        img = Image.open(img_path).convert("L")
        image_name = os.path.basename(img_path)
        patient_id = self.get_patient_id(image_name)
        side_view = self.get_side_view(image_name)

        if random.random() > 0.5:
            positive_img = img
            if self.transform_pos:
                positive_img = self.transform_pos(img)
                img = self.base_transform(img) 
            return img, positive_img, 1
        else:
            other_patients = [pid for pid in self.patient_data if pid != patient_id]
            if other_patients:
                negative_patient_id = random.choice(other_patients)
                negative_img_path = random.choice(self.patient_data[negative_patient_id])
            else:
                all_images = self.patient_data[patient_id]
                negative_img_path = random.choice([img_path for img_path in all_images if self.get_side_view(img_path) != side_view])
            negative_img = Image.open(negative_img_path).convert("L")
            if self.transform_neg:
                negative_img = self.transform_neg(negative_img)
                img = self.base_transform(img) 
            return img, negative_img, 0

# %%
base_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5]),
])

transform1 = transforms.Compose([
    base_transform,
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(degrees=15), # 你可以根据需要调整旋转角度
])

transform2 = transforms.Compose([
    base_transform,
    transforms.RandomRotation(degrees=5),  # 你可以根据需要调整旋转角度
])

# %%
dataset = CustomContrastiveDataset(data_dir=r"F:\Dataset\Train_tumor\train_phase2\rgb_all_png\train_extend_DBT_slice_rgb_patch3", base_transform=base_transform,transform1=transform1, transform2=transform2)

# %%
from torch.utils.data import DataLoader
train_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models

class ContrastiveNet(nn.Module):
    def __init__(self):
        super(ContrastiveNet, self).__init__()
        self.feature_extractor = models.resnet50(pretrained=False)
        self.feature_extractor.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        # 移除最后的全连接层
        self.feature_extractor.fc = nn.Identity()  # 移除全连接层，只保留特征提取部分
        # 全连接层
        self.fc = nn.Sequential(
            nn.Linear(2048, 256),  # ResNet18 的输出特征维度是512
            nn.ReLU(inplace=True),
            nn.Linear(256, 128)  # 输出特征维度为128
        )

    def forward(self, x):
        # 提取特征
        x = self.feature_extractor(x)
        x = self.fc(x)
        # L2归一化
        x = F.normalize(x, p=2, dim=1)
        return x

# %%
class ContrastiveLoss(nn.Module):
    def __init__(self, margin=1.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, feature1, feature2, label):
        distance = F.pairwise_distance(feature1, feature2)
        loss = torch.mean((1 - label) * torch.pow(distance, 2) +  # 正样本对
                          label * torch.pow(torch.clamp(self.margin - distance, min=0.0), 2))  # 负样本对
        return loss

class InfoNCELoss(nn.Module):
    def __init__(self, temperature=0.1):
        super(InfoNCELoss, self).__init__()
        self.temperature = temperature

    def forward(self, feature1, feature2,label):
        similarity_matrix = torch.matmul(feature1, feature2.T) / self.temperature
        pos_similarity = torch.diag(similarity_matrix)
        neg_similarity = torch.logsumexp(similarity_matrix, dim=1) - pos_similarity
        loss = -torch.mean((1 - label) * pos_similarity - label * neg_similarity)
        return loss

# %%
import torch.optim as optim
from torch.utils.data import DataLoader

model = ContrastiveNet()
criterion = ContrastiveLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

def train(model, train_loader, criterion, optimizer, num_epochs=150):
    model.train()
    best_loss = float('inf')
    best_model_state = None
    for epoch in range(num_epochs):
        epoch_loss = 0.0
        for batch in train_loader:
            img1, img2, label = batch
            feature1 = model(img1)
            feature2 = model(img2)
            loss = criterion(feature1, feature2,label)  # 如果使用 ContrastiveLoss，需要传入 label
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        avg_epoch_loss = epoch_loss / len(train_loader)
        print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {avg_epoch_loss:.4f}")
        
        if avg_epoch_loss < best_loss:
            best_loss = avg_epoch_loss
            best_model_state = model.state_dict()  # 保存最佳模型状态
        else:
            best_model_state = None

        
        if best_model_state is not None:
            torch.save(best_model_state, "best_contrastive_model_resnet50.pth")
            print(f"Saved best model with loss: {best_loss:.4f}")
# 开始训练
train(model, train_loader, criterion, optimizer, num_epochs=100)

# %%
import os
import json
from PIL import Image
from torch.utils.data import Dataset
import cv2

class CustomDataset(Dataset):
    def __init__(self, dataset_path, json_path, transform=None, augment_transform=None, n=2):
        self.dataset_path = dataset_path
        self.transform = transform
        self.augment_transform = augment_transform
        self.n = n

        with open(json_path, 'r') as f:
            self.labels = json.load(f)

        self.image_files = [f for f in os.listdir(dataset_path) if f.endswith('.png')]
    
    def __len__(self):
        return len(self.image_files) * self.n
    
    def _extract_prefix(self, filename):
        parts = filename.split('_')
        if len(parts) >= 3:
            prefix = '_'.join(parts[:3])
            view_char = parts[2]
            return prefix,view_char
        return filename  # 如果不足三个 '_'，返回原文件名
    
    def __getitem__(self, idx):
        original_idx = idx % len(self.image_files)

        img_name = self.image_files[original_idx]

        img_path = os.path.join(self.dataset_path, img_name)

        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # 读取灰度图像

        img_prefix,view_char = self._extract_prefix(img_name)
        if view_char.lower().startswith('r'):
            image = cv2.flip(image, 1)  # 水平翻转图像

        normalized_image = image.astype(np.float32) / 255.0
        normalized_image = (normalized_image * 255).astype(np.uint8)    
        rgb_image = cv2.applyColorMap(normalized_image, cv2.COLORMAP_JET)

        rgb_image = Image.fromarray(cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB))

        label = -1  # 默认标签
        for key in self.labels:
            key_prefix,_ = self._extract_prefix(key)
            if key_prefix == img_prefix:
                label = self.labels[key]
                break
        if idx >= len(self.image_files) and self.augment_transform:
            # 对数据增强的样本应用增强变换
            rgb_image = self.augment_transform(rgb_image)
        elif self.transform:
            # 对原始样本应用默认变换
            rgb_image = self.transform(rgb_image)
        single_channel_image = rgb_image[1].unsqueeze(0)
        return single_channel_image, label

# %%
class BinaryClassificationNet(nn.Module):
    def __init__(self, feature_extractor, num_classes=2, hidden_dim=64):
        super(BinaryClassificationNet, self).__init__()
        self.feature_extractor = feature_extractor  # 对比学习的特征提取器
        self.classifier = nn.Sequential(
            nn.Linear(128, hidden_dim),  # 假设特征维度是128
            nn.ReLU(inplace=True),
            nn.Linear(hidden_dim, num_classes)  # 二分类任务
        )
        # 冻结特征提取器的参数
        for param in self.feature_extractor.parameters():
            param.requires_grad = False

    def forward(self, x):
        features = self.feature_extractor(x)
        features = features.view(features.size(0), -1)
        logits = self.classifier(features)
        return logits  # 使用BCEWithLogitsLoss时不需要Sigmoid

# %%
contrastive_model = ContrastiveNet()
contrastive_model.load_state_dict(torch.load("best_contrastive_model_resnet50.pth"))
feature_extractor = contrastive_model

# %%
binary_model = BinaryClassificationNet(feature_extractor)

# %%
#criterion = nn.BCEWithLogitsLoss()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(binary_model.parameters(), lr=0.0001)

# %%
dataset_path = r"F:\Dataset\Test\test_phase2\rgb_all_png\test_extend_DBT_slice_rgb_patch3_split"
json_path = r"F:\Dataset\Test\results_test.json"


default_transform = transforms.Compose([
    transforms.Resize((224, 224)),  # 调整图片大小
    transforms.ToTensor(),          # 转换为Tensor
])

augment_transform = transforms.Compose([
    transforms.Resize((224, 224)),            # 调整图片大小
    transforms.RandomHorizontalFlip(p=0.5),  # 随机水平翻转
    transforms.RandomRotation(10),           # 随机旋转
    #transforms.ColorJitter(brightness=0.2, contrast=0.2),  # 随机调整亮度和对比度
    transforms.ToTensor(),                   # 转换为Tensor
])

dataset = CustomDataset(
    dataset_path=dataset_path,
    json_path=json_path,
    transform=default_transform,
    augment_transform=augment_transform,
    n=3
)

train_dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

val_dataset  = r"F:\Dataset\Val\val_phase2\rgb_all_png\val_extend_DBT_slice_rgb_patch3_split"
val_json = r"F:\Dataset\Val\results_val.json"

val_dataset =CustomDataset(
    dataset_path=val_dataset,
    json_path=val_json,
    transform=default_transform,
    augment_transform=augment_transform,
    n=2
)

val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             roc_auc_score, average_precision_score, matthews_corrcoef,
                             cohen_kappa_score, confusion_matrix, classification_report)
import numpy as np

def train_model(train_dataloader, val_dataloader, model, criterion, optimizer, num_epochs=10):
    best_auc = 0.0  # 用于保存最高的 AUC 值
    log_file = "training_log_resnet50.txt"  # 日志文件路径

    # 打开日志文件
    with open(log_file, "w") as f:
        f.write("Epoch\tTrain Loss\tTrain Accuracy\tTrain AUC\tTrain Precision\tTrain Sensitivity\tTrain Specificity\tTrain f1\tVal Accuracy\tVal AUC\tVal Precision\tVal Sensitivity\tVal Specificity\tVal f1\n")

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        train_preds = []
        train_labels = []

        for images, labels in train_dataloader:
            images = images.to(device)
            labels = labels.to(device)
            labels = labels.long()
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            preds = torch.argmax(outputs, dim=1)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            train_preds.extend(preds.detach().cpu().numpy())
            train_labels.extend(labels.cpu().numpy())

        
        train_loss = running_loss / len(train_dataloader)
        # train_accuracy = accuracy_score(train_labels, (np.array(train_preds) > 0.5).astype(int))
        # train_auc = roc_auc_score(train_labels, train_preds)
        # train_precision = precision_score(train_labels, (np.array(train_preds) > 0.5).astype(int))
        # train_sensitivity = recall_score(train_labels, (np.array(train_preds) > 0.5).astype(int))
        # train_specificity = recall_score(train_labels, (np.array(train_preds) > 0.5).astype(int), pos_label=0)
        # train_f1score = f1_score(train_labels, (np.array(train_preds) > 0.5).astype(int))
        train_accuracy = accuracy_score(train_labels, train_preds)
        train_auc = roc_auc_score(train_labels, train_preds)
        train_precision = precision_score(train_labels, train_preds)
        train_sensitivity = recall_score(train_labels, train_preds)
        train_specificity = recall_score(train_labels, train_preds, pos_label=0)
        train_f1score = f1_score(train_labels, train_preds)

        model.eval()
        val_preds = []
        val_labels = []

        with torch.no_grad():
            for images, labels in val_dataloader:
                images = images.to(device)
                labels = labels.to(device)
                labels = labels.long()
                outputs = model(images)
                preds = torch.argmax(outputs, dim=1)
                val_preds.extend(preds.detach().cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

        # val_accuracy = accuracy_score(val_labels, (np.array(val_preds) > 0.5).astype(int))
        # val_auc = roc_auc_score(val_labels, val_preds)
        # val_precision = precision_score(val_labels, (np.array(val_preds) > 0.5).astype(int))
        # val_sensitivity = recall_score(val_labels, (np.array(val_preds) > 0.5).astype(int))
        # val_specificity = recall_score(val_labels, (np.array(val_preds) > 0.5).astype(int), pos_label=0)
        # val_f1score = f1_score(val_labels, (np.array(val_preds) > 0.5).astype(int))
        val_accuracy = accuracy_score(val_labels, val_preds)
        val_auc = roc_auc_score(val_labels, val_preds)
        val_precision = precision_score(val_labels, val_preds)
        val_sensitivity = recall_score(val_labels, val_preds)
        val_specificity = recall_score(val_labels, val_preds, pos_label=0)
        val_f1score = f1_score(val_labels, val_preds)

        print(f"Epoch [{epoch + 1}/{num_epochs}], "
              f"Train Loss: {train_loss:.4f}, "
              f"Train Accuracy: {train_accuracy:.4f}, "
              f"Train AUC: {train_auc:.4f}, "
              f"Train Precision: {train_precision:.4f}, "
              f"Val Accuracy: {val_accuracy:.4f}, "
              f"Val AUC: {val_auc:.4f}, "
              f"Val Precision: {val_precision:.4f}")

        # 保存指标到日志文件
        with open(log_file, "a") as f:
            f.write(f"{epoch + 1}\t{train_loss:.4f}\t{train_accuracy:.4f}\t{train_auc:.4f}\t{train_precision:.4f}\t{train_sensitivity:.4f}\t{train_specificity:.4f}\t{train_f1score:.4f}\t"
                    f"{val_accuracy:.4f}\t{val_auc:.4f}\t{val_precision:.4f}\t{val_sensitivity:.4f}\t{val_specificity:.4f}\t{val_f1score:.4f}\n")

        if val_auc > best_auc:
            best_auc = val_auc
            torch.save(model.state_dict(), "best_model_resnet50.pth")
            print(f"New best model saved with AUC: {best_auc:.4f}")

model = binary_model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# BinaryClassificationNet(
#   (feature_extractor): ContrastiveNet(
#     (feature_extractor): ResNet(
#       (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Identity()
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=2048, out_features=256, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=256, out_features=128, bias=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %%
train_model(train_dataloader, val_dataloader, model, criterion, optimizer, num_epochs=3000)
# Out:
# Epoch [1/3000], Train Loss: 0.6663, Train Accuracy: 0.5798, Train AUC: 0.5817, Train Precision: 0.6100, Val Accuracy: 0.5435, Val AUC: 0.5399, Val Precision: 0.5714
# New best model saved with AUC: 0.5399
# Epoch [2/3000], Train Loss: 0.6756, Train Accuracy: 0.5621, Train AUC: 0.5640, Train Precision: 0.5911, Val Accuracy: 0.5556, Val AUC: 0.5522, Val Precision: 0.5909
# New best model saved with AUC: 0.5522
# Epoch [3/3000], Train Loss: 0.6685, Train Accuracy: 0.5736, Train AUC: 0.5755, Train Precision: 0.6035, Val Accuracy: 0.5459, Val AUC: 0.5424, Val Precision: 0.5755
# Epoch [4/3000], Train Loss: 0.6733, Train Accuracy: 0.5638, Train AUC: 0.5658, Train Precision: 0.5930, Val Accuracy: 0.5507, Val AUC: 0.5475, Val Precision: 0.5776
# Epoch [5/3000], Train Loss: 0.6701, Train Accuracy: 0.5709, Train AUC: 0.5728, Train Precision: 0.6004, Val Accuracy: 0.5507, Val AUC: 0.5478, Val Precision: 0.5726
# Epoch [6/3000], Train Loss: 0.6727, Train Accuracy: 0.5585, Train AUC: 0.5604, Train Precision: 0.5869, Val Accuracy: 0.5435, Val AUC: 0.5398, Val Precision: 0.5728
# Epoch [7/3000], Train Loss: 0.6671, Train Accuracy: 0.5745, Train AUC: 0.5766, Train Precision: 0.6059, Val Accuracy: 0.5531, Val AUC: 0.5495, Val Precision: 0.5922
# Epoch [8/3000], Train Loss: 0.6713, Train Accuracy: 0.5621, Train AUC: 0.5641, Train Precision: 0.5918, Val Accuracy: 0.5556, Val AUC: 0.5522, Val Precision: 0.5909
# Epoch [9/3000], Train Loss: 0.6741, Train Accuracy: 0.5674, Train AUC: 0.5695, Train Precision: 0.5980, Val Accuracy: 0.5435, Val AUC: 0.5403, Val Precision: 0.5641
# Epoch [10/3000], Train Loss: 0.6716, Train Accuracy: 0.5736, Train AUC: 0.5757, Train Precision: 0.6047, Val Accuracy: 0.5459, Val AUC: 0.5424, Val Precision: 0.5741
# Epoch [11/3000], Train Loss: 0.6696, Train Accuracy: 0.5691, Train AUC: 0.5715, Train Precision: 0.6008, Val Accuracy: 0.5386, Val AUC: 0.5349, Val Precision: 0.5657
# Epoch [12/3000], Train Loss: 0.6680, Train Accuracy: 0.5629, Train AUC: 0.5651, Train Precision: 0.5933, Val Accuracy: 0.5531, Val AUC: 0.5496, Val Precision: 0.5888
# Epoch [13/3000], Train Loss: 0.6703, Train Accuracy: 0.5656, Train AUC: 0.5678, Train Precision: 0.5961, Val Accuracy: 0.5314, Val AUC: 0.5279, Val Precision: 0.5463
# Epoch [14/3000], Train Loss: 0.6729, Train Accuracy: 0.5638, Train AUC: 0.5658, Train Precision: 0.5930, Val Accuracy: 0.5483, Val AUC: 0.5448, Val Precision: 0.5794
# Epoch [15/3000], Train Loss: 0.6697, Train Accuracy: 0.5683, Train AUC: 0.5705, Train Precision: 0.5992, Val Accuracy: 0.5556, Val AUC: 0.5522, Val Precision: 0.5909
# Epoch [16/3000], Train Loss: 0.6704, Train Accuracy: 0.5629, Train AUC: 0.5652, Train Precision: 0.5937, Val Accuracy: 0.5483, Val AUC: 0.5449, Val Precision: 0.5780
# Epoch [17/3000], Train Loss: 0.6676, Train Accuracy: 0.5709, Train AUC: 0.5730, Train Precision: 0.6016, Val Accuracy: 0.5507, Val AUC: 0.5473, Val Precision: 0.5833
# Epoch [18/3000], Train Loss: 0.6753, Train Accuracy: 0.5585, Train AUC: 0.5606, Train Precision: 0.5879, Val Accuracy: 0.5411, Val AUC: 0.5380, Val Precision: 0.5583
# Epoch [19/3000], Train Loss: 0.6703, Train Accuracy: 0.5656, Train AUC: 0.5679, Train Precision: 0.5968, Val Accuracy: 0.5556, Val AUC: 0.5522, Val Precision: 0.5909
# Epoch [20/3000], Train Loss: 0.6717, Train Accuracy: 0.5638, Train AUC: 0.5663, Train Precision: 0.5956, Val Accuracy: 0.5531, Val AUC: 0.5504, Val Precision: 0.5736
# Epoch [21/3000], Train Loss: 0.6700, Train Accuracy: 0.5683, Train AUC: 0.5708, Train Precision: 0.6008, Val Accuracy: 0.5531, Val AUC: 0.5503, Val Precision: 0.5760
# Epoch [22/3000], Train Loss: 0.6710, Train Accuracy: 0.5745, Train AUC: 0.5766, Train Precision: 0.6059, Val Accuracy: 0.5459, Val AUC: 0.5429, Val Precision: 0.5656
# Epoch [23/3000], Train Loss: 0.6701, Train Accuracy: 0.5656, Train AUC: 0.5681, Train Precision: 0.5976, Val Accuracy: 0.5556, Val AUC: 0.5523, Val Precision: 0.5877
# New best model saved with AUC: 0.5523
# Epoch [24/3000], Train Loss: 0.6729, Train Accuracy: 0.5629, Train AUC: 0.5646, Train Precision: 0.5908, Val Accuracy: 0.5507, Val AUC: 0.5473, Val Precision: 0.5818
# Epoch [25/3000], Train Loss: 0.6724, Train Accuracy: 0.5612, Train AUC: 0.5634, Train Precision: 0.5914, Val Accuracy: 0.5628, Val AUC: 0.5596, Val Precision: 0.6000
# New best model saved with AUC: 0.5596
# Epoch [26/3000], Train Loss: 0.6702, Train Accuracy: 0.5816, Train AUC: 0.5837, Train Precision: 0.6137, Val Accuracy: 0.5483, Val AUC: 0.5451, Val Precision: 0.5739
# Epoch [27/3000], Train Loss: 0.6674, Train Accuracy: 0.5754, Train AUC: 0.5776, Train Precision: 0.6071, Val Accuracy: 0.5556, Val AUC: 0.5524, Val Precision: 0.5862
# Epoch [28/3000], Train Loss: 0.6713, Train Accuracy: 0.5709, Train AUC: 0.5730, Train Precision: 0.6016, Val Accuracy: 0.5459, Val AUC: 0.5426, Val Precision: 0.5714
# Epoch [29/3000], Train Loss: 0.6690, Train Accuracy: 0.5709, Train AUC: 0.5732, Train Precision: 0.6028, Val Accuracy: 0.5338, Val AUC: 0.5305, Val Precision: 0.5487
# Epoch [30/3000], Train Loss: 0.6698, Train Accuracy: 0.5700, Train AUC: 0.5721, Train Precision: 0.6004, Val Accuracy: 0.5459, Val AUC: 0.5425, Val Precision: 0.5727
# Epoch [31/3000], Train Loss: 0.6706, Train Accuracy: 0.5674, Train AUC: 0.5695, Train Precision: 0.5977, Val Accuracy: 0.5362, Val AUC: 0.5326, Val Precision: 0.5588
# Epoch [32/3000], Train Loss: 0.6719, Train Accuracy: 0.5718, Train AUC: 0.5738, Train Precision: 0.6019, Val Accuracy: 0.5507, Val AUC: 0.5472, Val Precision: 0.5849
# Epoch [33/3000], Train Loss: 0.6699, Train Accuracy: 0.5745, Train AUC: 0.5769, Train Precision: 0.6071, Val Accuracy: 0.5580, Val AUC: 0.5549, Val Precision: 0.5882
# Epoch [34/3000], Train Loss: 0.6683, Train Accuracy: 0.5762, Train AUC: 0.5782, Train Precision: 0.6066, Val Accuracy: 0.5362, Val AUC: 0.5332, Val Precision: 0.5500
# Epoch [35/3000], Train Loss: 0.6727, Train Accuracy: 0.5567, Train AUC: 0.5591, Train Precision: 0.5873, Val Accuracy: 0.5531, Val AUC: 0.5497, Val Precision: 0.5872
# Epoch [36/3000], Train Loss: 0.6715, Train Accuracy: 0.5683, Train AUC: 0.5705, Train Precision: 0.5992, Val Accuracy: 0.5362, Val AUC: 0.5331, Val Precision: 0.5517
# Epoch [37/3000], Train Loss: 0.6685, Train Accuracy: 0.5700, Train AUC: 0.5723, Train Precision: 0.6016, Val Accuracy: 0.5411, Val AUC: 0.5374, Val Precision: 0.5686
# Epoch [38/3000], Train Loss: 0.6701, Train Accuracy: 0.5718, Train AUC: 0.5744, Train Precision: 0.6052, Val Accuracy: 0.5556, Val AUC: 0.5522, Val Precision: 0.5909
# Epoch [39/3000], Train Loss: 0.6719, Train Accuracy: 0.5647, Train AUC: 0.5667, Train Precision: 0.5942, Val Accuracy: 0.5483, Val AUC: 0.5451, Val Precision: 0.5739
# Epoch [40/3000], Train Loss: 0.6703, Train Accuracy: 0.5709, Train AUC: 0.5729, Train Precision: 0.6012, Val Accuracy: 0.5386, Val AUC: 0.5351, Val Precision: 0.5619
# Epoch [41/3000], Train Loss: 0.6719, Train Accuracy: 0.5691, Train AUC: 0.5709, Train Precision: 0.5981, Val Accuracy: 0.5483, Val AUC: 0.5445, Val Precision: 0.5859
# Epoch [42/3000], Train Loss: 0.6695, Train Accuracy: 0.5718, Train AUC: 0.5739, Train Precision: 0.6027, Val Accuracy: 0.5362, Val AUC: 0.5327, Val Precision: 0.5566
# Epoch [43/3000], Train Loss: 0.6690, Train Accuracy: 0.5762, Train AUC: 0.5786, Train Precision: 0.6087, Val Accuracy: 0.5483, Val AUC: 0.5447, Val Precision: 0.5810
# Epoch [44/3000], Train Loss: 0.6688, Train Accuracy: 0.5745, Train AUC: 0.5763, Train Precision: 0.6042, Val Accuracy: 0.5386, Val AUC: 0.5356, Val Precision: 0.5546
# Epoch [45/3000], Train Loss: 0.6720, Train Accuracy: 0.5638, Train AUC: 0.5667, Train Precision: 0.5976, Val Accuracy: 0.5507, Val AUC: 0.5474, Val Precision: 0.5804
# Epoch [46/3000], Train Loss: 0.6728, Train Accuracy: 0.5656, Train AUC: 0.5678, Train Precision: 0.5965, Val Accuracy: 0.5411, Val AUC: 0.5375, Val Precision: 0.5660
# Epoch [47/3000], Train Loss: 0.6728, Train Accuracy: 0.5638, Train AUC: 0.5660, Train Precision: 0.5941, Val Accuracy: 0.5362, Val AUC: 0.5327, Val Precision: 0.5566
# Epoch [48/3000], Train Loss: 0.6725, Train Accuracy: 0.5603, Train AUC: 0.5626, Train Precision: 0.5909, Val Accuracy: 0.5483, Val AUC: 0.5450, Val Precision: 0.5766
# Epoch [49/3000], Train Loss: 0.6699, Train Accuracy: 0.5718, Train AUC: 0.5740, Train Precision: 0.6031, Val Accuracy: 0.5507, Val AUC: 0.5476, Val Precision: 0.5763
# Epoch [50/3000], Train Loss: 0.6705, Train Accuracy: 0.5727, Train AUC: 0.5746, Train Precision: 0.6023, Val Accuracy: 0.5483, Val AUC: 0.5450, Val Precision: 0.5766
# Epoch [51/3000], Train Loss: 0.6677, Train Accuracy: 0.5638, Train AUC: 0.5663, Train Precision: 0.5956, Val Accuracy: 0.5483, Val AUC: 0.5447, Val Precision: 0.5810
# Epoch [52/3000], Train Loss: 0.6689, Train Accuracy: 0.5833, Train AUC: 0.5858, Train Precision: 0.6171, Val Accuracy: 0.5459, Val AUC: 0.5426, Val Precision: 0.5702
# Epoch [53/3000], Train Loss: 0.6722, Train Accuracy: 0.5638, Train AUC: 0.5657, Train Precision: 0.5927, Val Accuracy: 0.5435, Val AUC: 0.5398, Val Precision: 0.5743
# Epoch [54/3000], Train Loss: 0.6722, Train Accuracy: 0.5674, Train AUC: 0.5696, Train Precision: 0.5984, Val Accuracy: 0.5411, Val AUC: 0.5377, Val Precision: 0.5625
# Epoch [55/3000], Train Loss: 0.6700, Train Accuracy: 0.5709, Train AUC: 0.5731, Train Precision: 0.6020, Val Accuracy: 0.5459, Val AUC: 0.5423, Val Precision: 0.5769
# Epoch [56/3000], Train Loss: 0.6693, Train Accuracy: 0.5727, Train AUC: 0.5752, Train Precision: 0.6060, Val Accuracy: 0.5459, Val AUC: 0.5425, Val Precision: 0.5727
# Epoch [57/3000], Train Loss: 0.6700, Train Accuracy: 0.5674, Train AUC: 0.5698, Train Precision: 0.5996, Val Accuracy: 0.5531, Val AUC: 0.5504, Val Precision: 0.5748
# Epoch [58/3000], Train Loss: 0.6709, Train Accuracy: 0.5594, Train AUC: 0.5617, Train Precision: 0.5897, Val Accuracy: 0.5411, Val AUC: 0.5378, Val Precision: 0.5614
# Epoch [59/3000], Train Loss: 0.6716, Train Accuracy: 0.5638, Train AUC: 0.5661, Train Precision: 0.5949, Val Accuracy: 0.5411, Val AUC: 0.5377, Val Precision: 0.5625
# Epoch [60/3000], Train Loss: 0.6687, Train Accuracy: 0.5700, Train AUC: 0.5722, Train Precision: 0.6008, Val Accuracy: 0.5362, Val AUC: 0.5328, Val Precision: 0.5545
# Epoch [61/3000], Train Loss: 0.6736, Train Accuracy: 0.5612, Train AUC: 0.5630, Train Precision: 0.5896, Val Accuracy: 0.5266, Val AUC: 0.5229, Val Precision: 0.5392
# Epoch [62/3000], Train Loss: 0.6679, Train Accuracy: 0.5816, Train AUC: 0.5841, Train Precision: 0.6155, Val Accuracy: 0.5338, Val AUC: 0.5304, Val Precision: 0.5505
# Epoch [63/3000], Train Loss: 0.6683, Train Accuracy: 0.5718, Train AUC: 0.5739, Train Precision: 0.6027, Val Accuracy: 0.5483, Val AUC: 0.5450, Val Precision: 0.5752
# Epoch [64/3000], Train Loss: 0.6687, Train Accuracy: 0.5665, Train AUC: 0.5689, Train Precision: 0.5984, Val Accuracy: 0.5459, Val AUC: 0.5424, Val Precision: 0.5755
# Epoch [65/3000], Train Loss: 0.6701, Train Accuracy: 0.5629, Train AUC: 0.5648, Train Precision: 0.5919, Val Accuracy: 0.5459, Val AUC: 0.5426, Val Precision: 0.5702
# Epoch [66/3000], Train Loss: 0.6712, Train Accuracy: 0.5736, Train AUC: 0.5759, Train Precision: 0.6059, Val Accuracy: 0.5338, Val AUC: 0.5306, Val Precision: 0.5478
# Epoch [67/3000], Train Loss: 0.6691, Train Accuracy: 0.5771, Train AUC: 0.5798, Train Precision: 0.6117, Val Accuracy: 0.5459, Val AUC: 0.5422, Val Precision: 0.5784
# Epoch [68/3000], Train Loss: 0.6680, Train Accuracy: 0.5745, Train AUC: 0.5768, Train Precision: 0.6067, Val Accuracy: 0.5411, Val AUC: 0.5375, Val Precision: 0.5673
# Epoch [69/3000], Train Loss: 0.6686, Train Accuracy: 0.5665, Train AUC: 0.5688, Train Precision: 0.5976, Val Accuracy: 0.5435, Val AUC: 0.5403, Val Precision: 0.5652
# Epoch [70/3000], Train Loss: 0.6694, Train Accuracy: 0.5621, Train AUC: 0.5641, Train Precision: 0.5918, Val Accuracy: 0.5483, Val AUC: 0.5448, Val Precision: 0.5794
# Epoch [71/3000], Train Loss: 0.6691, Train Accuracy: 0.5691, Train AUC: 0.5713, Train Precision: 0.6000, Val Accuracy: 0.5435, Val AUC: 0.5403, Val Precision: 0.5641
# Epoch [72/3000], Train Loss: 0.6673, Train Accuracy: 0.5665, Train AUC: 0.5687, Train Precision: 0.5972, Val Accuracy: 0.5411, Val AUC: 0.5375, Val Precision: 0.5673
# Epoch [73/3000], Train Loss: 0.6718, Train Accuracy: 0.5656, Train AUC: 0.5681, Train Precision: 0.5980, Val Accuracy: 0.5411, Val AUC: 0.5375, Val Precision: 0.5673
# Epoch [74/3000], Train Loss: 0.6722, Train Accuracy: 0.5629, Train AUC: 0.5652, Train Precision: 0.5937, Val Accuracy: 0.5386, Val AUC: 0.5353, Val Precision: 0.5586
# Epoch [75/3000], Train Loss: 0.6733, Train Accuracy: 0.5807, Train AUC: 0.5828, Train Precision: 0.6125, Val Accuracy: 0.5411, Val AUC: 0.5380, Val Precision: 0.5593
# Epoch [76/3000], Train Loss: 0.6690, Train Accuracy: 0.5709, Train AUC: 0.5737, Train Precision: 0.6053, Val Accuracy: 0.5411, Val AUC: 0.5377, Val Precision: 0.5636
# Epoch [77/3000], Train Loss: 0.6690, Train Accuracy: 0.5727, Train AUC: 0.5750, Train Precision: 0.6047, Val Accuracy: 0.5362, Val AUC: 0.5326, Val Precision: 0.5577
# Epoch [78/3000], Train Loss: 0.6724, Train Accuracy: 0.5700, Train AUC: 0.5721, Train Precision: 0.6004, Val Accuracy: 0.5459, Val AUC: 0.5426, Val Precision: 0.5702
# Epoch [79/3000], Train Loss: 0.6740, Train Accuracy: 0.5550, Train AUC: 0.5576, Train Precision: 0.5867, Val Accuracy: 0.5507, Val AUC: 0.5472, Val Precision: 0.5849
# Epoch [80/3000], Train Loss: 0.6715, Train Accuracy: 0.5656, Train AUC: 0.5682, Train Precision: 0.5984, Val Accuracy: 0.5483, Val AUC: 0.5448, Val Precision: 0.5794
# Epoch [81/3000], Train Loss: 0.6709, Train Accuracy: 0.5629, Train AUC: 0.5655, Train Precision: 0.5952, Val Accuracy: 0.5290, Val AUC: 0.5256, Val Precision: 0.5413
# Epoch [82/3000], Train Loss: 0.6712, Train Accuracy: 0.5638, Train AUC: 0.5663, Train Precision: 0.5956, Val Accuracy: 0.5386, Val AUC: 0.5354, Val Precision: 0.5565
# Epoch [83/3000], Train Loss: 0.6708, Train Accuracy: 0.5736, Train AUC: 0.5764, Train Precision: 0.6085, Val Accuracy: 0.5411, Val AUC: 0.5377, Val Precision: 0.5636
# Epoch [84/3000], Train Loss: 0.6701, Train Accuracy: 0.5816, Train AUC: 0.5842, Train Precision: 0.6165, Val Accuracy: 0.5507, Val AUC: 0.5476, Val Precision: 0.5763
# Epoch [85/3000], Train Loss: 0.6701, Train Accuracy: 0.5691, Train AUC: 0.5713, Train Precision: 0.6000, Val Accuracy: 0.5362, Val AUC: 0.5330, Val Precision: 0.5526
# Epoch [86/3000], Train Loss: 0.6690, Train Accuracy: 0.5745, Train AUC: 0.5771, Train Precision: 0.6084, Val Accuracy: 0.5411, Val AUC: 0.5375, Val Precision: 0.5673
# Epoch [87/3000], Train Loss: 0.6691, Train Accuracy: 0.5709, Train AUC: 0.5735, Train Precision: 0.6040, Val Accuracy: 0.5362, Val AUC: 0.5327, Val Precision: 0.5566
# Epoch [88/3000], Train Loss: 0.6721, Train Accuracy: 0.5612, Train AUC: 0.5635, Train Precision: 0.5921, Val Accuracy: 0.5483, Val AUC: 0.5450, Val Precision: 0.5752
# Epoch [89/3000], Train Loss: 0.6709, Train Accuracy: 0.5665, Train AUC: 0.5687, Train Precision: 0.5972, Val Accuracy: 0.5386, Val AUC: 0.5351, Val Precision: 0.5619
# Epoch [90/3000], Train Loss: 0.6709, Train Accuracy: 0.5647, Train AUC: 0.5676, Train Precision: 0.5988, Val Accuracy: 0.5362, Val AUC: 0.5329, Val Precision: 0.5536
# Epoch [91/3000], Train Loss: 0.6694, Train Accuracy: 0.5727, Train AUC: 0.5754, Train Precision: 0.6069, Val Accuracy: 0.5483, Val AUC: 0.5454, Val Precision: 0.5691
# Epoch [92/3000], Train Loss: 0.6738, Train Accuracy: 0.5683, Train AUC: 0.5711, Train Precision: 0.6024, Val Accuracy: 0.5435, Val AUC: 0.5405, Val Precision: 0.5610
# Epoch [93/3000], Train Loss: 0.6665, Train Accuracy: 0.5691, Train AUC: 0.5720, Train Precision: 0.6037, Val Accuracy: 0.5459, Val AUC: 0.5424, Val Precision: 0.5755
# Epoch [94/3000], Train Loss: 0.6741, Train Accuracy: 0.5683, Train AUC: 0.5705, Train Precision: 0.5996, Val Accuracy: 0.5507, Val AUC: 0.5475, Val Precision: 0.5789
# Epoch [95/3000], Train Loss: 0.6728, Train Accuracy: 0.5621, Train AUC: 0.5646, Train Precision: 0.5940, Val Accuracy: 0.5483, Val AUC: 0.5452, Val Precision: 0.5714
# Epoch [96/3000], Train Loss: 0.6709, Train Accuracy: 0.5638, Train AUC: 0.5662, Train Precision: 0.5952, Val Accuracy: 0.5362, Val AUC: 0.5326, Val Precision: 0.5577
# Epoch [97/3000], Train Loss: 0.6703, Train Accuracy: 0.5683, Train AUC: 0.5712, Train Precision: 0.6033, Val Accuracy: 0.5411, Val AUC: 0.5377, Val Precision: 0.5636
# Epoch [98/3000], Train Loss: 0.6730, Train Accuracy: 0.5709, Train AUC: 0.5735, Train Precision: 0.6040, Val Accuracy: 0.5386, Val AUC: 0.5356, Val Precision: 0.5546
# Epoch [99/3000], Train Loss: 0.6649, Train Accuracy: 0.5833, Train AUC: 0.5862, Train Precision: 0.6199, Val Accuracy: 0.5507, Val AUC: 0.5476, Val Precision: 0.5763
# Epoch [100/3000], Train Loss: 0.6678, Train Accuracy: 0.5833, Train AUC: 0.5858, Train Precision: 0.6175, Val Accuracy: 0.5411, Val AUC: 0.5377, Val Precision: 0.5625
# Epoch [101/3000], Train Loss: 0.6701, Train Accuracy: 0.5691, Train AUC: 0.5718, Train Precision: 0.6024, Val Accuracy: 0.5314, Val AUC: 0.5279, Val Precision: 0.5472
# Epoch [102/3000], Train Loss: 0.6705, Train Accuracy: 0.5621, Train AUC: 0.5643, Train Precision: 0.5925, Val Accuracy: 0.5386, Val AUC: 0.5353, Val Precision: 0.5586
# Epoch [103/3000], Train Loss: 0.6694, Train Accuracy: 0.5745, Train AUC: 0.5774, Train Precision: 0.6102, Val Accuracy: 0.5386, Val AUC: 0.5353, Val Precision: 0.5586
# Epoch [104/3000], Train Loss: 0.6723, Train Accuracy: 0.5727, Train AUC: 0.5756, Train Precision: 0.6082, Val Accuracy: 0.5556, Val AUC: 0.5524, Val Precision: 0.5862
# Epoch [105/3000], Train Loss: 0.6727, Train Accuracy: 0.5665, Train AUC: 0.5689, Train Precision: 0.5984, Val Accuracy: 0.5531, Val AUC: 0.5501, Val Precision: 0.5798
# Epoch [106/3000], Train Loss: 0.6735, Train Accuracy: 0.5638, Train AUC: 0.5666, Train Precision: 0.5972, Val Accuracy: 0.5435, Val AUC: 0.5401, Val Precision: 0.5688
# Epoch [107/3000], Train Loss: 0.6698, Train Accuracy: 0.5612, Train AUC: 0.5637, Train Precision: 0.5928, Val Accuracy: 0.5386, Val AUC: 0.5355, Val Precision: 0.5556
# Epoch [108/3000], Train Loss: 0.6728, Train Accuracy: 0.5638, Train AUC: 0.5665, Train Precision: 0.5968, Val Accuracy: 0.5435, Val AUC: 0.5403, Val Precision: 0.5641
# Epoch [109/3000], Train Loss: 0.6691, Train Accuracy: 0.5700, Train AUC: 0.5725, Train Precision: 0.6028, Val Accuracy: 0.5362, Val AUC: 0.5330, Val Precision: 0.5526
# Epoch [110/3000], Train Loss: 0.6696, Train Accuracy: 0.5736, Train AUC: 0.5765, Train Precision: 0.6090, Val Accuracy: 0.5386, Val AUC: 0.5353, Val Precision: 0.5586
# Epoch [111/3000], Train Loss: 0.6687, Train Accuracy: 0.5754, Train AUC: 0.5783, Train Precision: 0.6110, Val Accuracy: 0.5531, Val AUC: 0.5501, Val Precision: 0.5798
# Epoch [112/3000], Train Loss: 0.6692, Train Accuracy: 0.5727, Train AUC: 0.5756, Train Precision: 0.6082, Val Accuracy: 0.5531, Val AUC: 0.5501, Val Precision: 0.5798
# Epoch [113/3000], Train Loss: 0.6716, Train Accuracy: 0.5700, Train AUC: 0.5726, Train Precision: 0.6032, Val Accuracy: 0.5362, Val AUC: 0.5331, Val Precision: 0.5517
# Epoch [114/3000], Train Loss: 0.6672, Train Accuracy: 0.5771, Train AUC: 0.5796, Train Precision: 0.6108, Val Accuracy: 0.5314, Val AUC: 0.5282, Val Precision: 0.5431
# Epoch [115/3000], Train Loss: 0.6683, Train Accuracy: 0.5771, Train AUC: 0.5795, Train Precision: 0.6099, Val Accuracy: 0.5435, Val AUC: 0.5401, Val Precision: 0.5676
# Epoch [116/3000], Train Loss: 0.6707, Train Accuracy: 0.5656, Train AUC: 0.5684, Train Precision: 0.5996, Val Accuracy: 0.5411, Val AUC: 0.5377, Val Precision: 0.5625
# Epoch [117/3000], Train Loss: 0.6691, Train Accuracy: 0.5612, Train AUC: 0.5644, Train Precision: 0.5967, Val Accuracy: 0.5338, Val AUC: 0.5302, Val Precision: 0.5534
# Epoch [118/3000], Train Loss: 0.6722, Train Accuracy: 0.5718, Train AUC: 0.5748, Train Precision: 0.6078, Val Accuracy: 0.5386, Val AUC: 0.5355, Val Precision: 0.5556
# Epoch [119/3000], Train Loss: 0.6652, Train Accuracy: 0.5860, Train AUC: 0.5891, Train Precision: 0.6242, Val Accuracy: 0.5217, Val AUC: 0.5181, Val Precision: 0.5288
# Epoch [120/3000], Train Loss: 0.6666, Train Accuracy: 0.5762, Train AUC: 0.5789, Train Precision: 0.6109, Val Accuracy: 0.5507, Val AUC: 0.5474, Val Precision: 0.5804
# Epoch [121/3000], Train Loss: 0.6688, Train Accuracy: 0.5665, Train AUC: 0.5689, Train Precision: 0.5984, Val Accuracy: 0.5338, Val AUC: 0.5306, Val Precision: 0.5478
# Epoch [122/3000], Train Loss: 0.6678, Train Accuracy: 0.5736, Train AUC: 0.5762, Train Precision: 0.6076, Val Accuracy: 0.5459, Val AUC: 0.5429, Val Precision: 0.5667
# Epoch [123/3000], Train Loss: 0.6697, Train Accuracy: 0.5709, Train AUC: 0.5738, Train Precision: 0.6061, Val Accuracy: 0.5314, Val AUC: 0.5279, Val Precision: 0.5472
# Epoch [124/3000], Train Loss: 0.6735, Train Accuracy: 0.5656, Train AUC: 0.5685, Train Precision: 0.6000, Val Accuracy: 0.5411, Val AUC: 0.5380, Val Precision: 0.5593
# Epoch [125/3000], Train Loss: 0.6698, Train Accuracy: 0.5771, Train AUC: 0.5797, Train Precision: 0.6112, Val Accuracy: 0.5435, Val AUC: 0.5403, Val Precision: 0.5652
# Epoch [126/3000], Train Loss: 0.6679, Train Accuracy: 0.5691, Train AUC: 0.5715, Train Precision: 0.6012, Val Accuracy: 0.5459, Val AUC: 0.5426, Val Precision: 0.5702
# Epoch [127/3000], Train Loss: 0.6692, Train Accuracy: 0.5700, Train AUC: 0.5725, Train Precision: 0.6028, Val Accuracy: 0.5386, Val AUC: 0.5358, Val Precision: 0.5520
# Epoch [128/3000], Train Loss: 0.6688, Train Accuracy: 0.5789, Train AUC: 0.5813, Train Precision: 0.6119, Val Accuracy: 0.5411, Val AUC: 0.5380, Val Precision: 0.5593
# Epoch [129/3000], Train Loss: 0.6704, Train Accuracy: 0.5656, Train AUC: 0.5682, Train Precision: 0.5984, Val Accuracy: 0.5386, Val AUC: 0.5356, Val Precision: 0.5546
# Epoch [130/3000], Train Loss: 0.6708, Train Accuracy: 0.5762, Train AUC: 0.5794, Train Precision: 0.6136, Val Accuracy: 0.5459, Val AUC: 0.5428, Val Precision: 0.5678
# Epoch [131/3000], Train Loss: 0.6690, Train Accuracy: 0.5683, Train AUC: 0.5707, Train Precision: 0.6004, Val Accuracy: 0.5507, Val AUC: 0.5476, Val Precision: 0.5763
# Epoch [132/3000], Train Loss: 0.6674, Train Accuracy: 0.5798, Train AUC: 0.5824, Train Precision: 0.6145, Val Accuracy: 0.5386, Val AUC: 0.5353, Val Precision: 0.5586
# Epoch [133/3000], Train Loss: 0.6711, Train Accuracy: 0.5594, Train AUC: 0.5617, Train Precision: 0.5897, Val Accuracy: 0.5459, Val AUC: 0.5429, Val Precision: 0.5667
# Epoch [134/3000], Train Loss: 0.6724, Train Accuracy: 0.5647, Train AUC: 0.5671, Train Precision: 0.5960, Val Accuracy: 0.5483, Val AUC: 0.5450, Val Precision: 0.5752
# Epoch [135/3000], Train Loss: 0.6697, Train Accuracy: 0.5745, Train AUC: 0.5774, Train Precision: 0.6102, Val Accuracy: 0.5435, Val AUC: 0.5403, Val Precision: 0.5652
# Epoch [136/3000], Train Loss: 0.6681, Train Accuracy: 0.5629, Train AUC: 0.5657, Train Precision: 0.5960, Val Accuracy: 0.5338, Val AUC: 0.5305, Val Precision: 0.5487
# Epoch [137/3000], Train Loss: 0.6725, Train Accuracy: 0.5700, Train AUC: 0.5730, Train Precision: 0.6053, Val Accuracy: 0.5362, Val AUC: 0.5329, Val Precision: 0.5536
# Epoch [138/3000], Train Loss: 0.6681, Train Accuracy: 0.5754, Train AUC: 0.5780, Train Precision: 0.6097, Val Accuracy: 0.5435, Val AUC: 0.5403, Val Precision: 0.5652
# Epoch [139/3000], Train Loss: 0.6730, Train Accuracy: 0.5709, Train AUC: 0.5732, Train Precision: 0.6024, Val Accuracy: 0.5459, Val AUC: 0.5429, Val Precision: 0.5656
# Epoch [140/3000], Train Loss: 0.6704, Train Accuracy: 0.5629, Train AUC: 0.5658, Train Precision: 0.5967, Val Accuracy: 0.5459, Val AUC: 0.5428, Val Precision: 0.5678
# Epoch [141/3000], Train Loss: 0.6688, Train Accuracy: 0.5691, Train AUC: 0.5715, Train Precision: 0.6012, Val Accuracy: 0.5435, Val AUC: 0.5405, Val Precision: 0.5610
# Epoch [142/3000], Train Loss: 0.6631, Train Accuracy: 0.5798, Train AUC: 0.5820, Train Precision: 0.6118, Val Accuracy: 0.5507, Val AUC: 0.5477, Val Precision: 0.5750
# Epoch [143/3000], Train Loss: 0.6714, Train Accuracy: 0.5665, Train AUC: 0.5692, Train Precision: 0.6000, Val Accuracy: 0.5531, Val AUC: 0.5500, Val Precision: 0.5812
# Epoch [144/3000], Train Loss: 0.6696, Train Accuracy: 0.5904, Train AUC: 0.5929, Train Precision: 0.6255, Val Accuracy: 0.5531, Val AUC: 0.5501, Val Precision: 0.5798
# Epoch [145/3000], Train Loss: 0.6686, Train Accuracy: 0.5691, Train AUC: 0.5719, Train Precision: 0.6032, Val Accuracy: 0.5459, Val AUC: 0.5426, Val Precision: 0.5702
# Epoch [146/3000], Train Loss: 0.6712, Train Accuracy: 0.5621, Train AUC: 0.5647, Train Precision: 0.5944, Val Accuracy: 0.5411, Val AUC: 0.5381, Val Precision: 0.5574
# Epoch [147/3000], Train Loss: 0.6714, Train Accuracy: 0.5700, Train AUC: 0.5728, Train Precision: 0.6045, Val Accuracy: 0.5483, Val AUC: 0.5451, Val Precision: 0.5739
# Epoch [148/3000], Train Loss: 0.6640, Train Accuracy: 0.5789, Train AUC: 0.5820, Train Precision: 0.6160, Val Accuracy: 0.5024, Val AUC: 0.4996, Val Precision: 0.4921
# Epoch [149/3000], Train Loss: 0.6689, Train Accuracy: 0.5718, Train AUC: 0.5746, Train Precision: 0.6065, Val Accuracy: 0.5483, Val AUC: 0.5452, Val Precision: 0.5714
# Epoch [150/3000], Train Loss: 0.6654, Train Accuracy: 0.5745, Train AUC: 0.5770, Train Precision: 0.6080, Val Accuracy: 0.5483, Val AUC: 0.5453, Val Precision: 0.5702
# Epoch [151/3000], Train Loss: 0.6670, Train Accuracy: 0.5824, Train AUC: 0.5847, Train Precision: 0.6149, Val Accuracy: 0.5435, Val AUC: 0.5402, Val Precision: 0.5664
# Epoch [152/3000], Train Loss: 0.6730, Train Accuracy: 0.5621, Train AUC: 0.5648, Train Precision: 0.5951, Val Accuracy: 0.5314, Val AUC: 0.5279, Val Precision: 0.5463
# Epoch [153/3000], Train Loss: 0.6701, Train Accuracy: 0.5789, Train AUC: 0.5816, Train Precision: 0.6137, Val Accuracy: 0.5459, Val AUC: 0.5425, Val Precision: 0.5727
# Epoch [154/3000], Train Loss: 0.6696, Train Accuracy: 0.5656, Train AUC: 0.5685, Train Precision: 0.6000, Val Accuracy: 0.5435, Val AUC: 0.5403, Val Precision: 0.5641
# Epoch [155/3000], Train Loss: 0.6702, Train Accuracy: 0.5718, Train AUC: 0.5746, Train Precision: 0.6065, Val Accuracy: 0.5290, Val AUC: 0.5256, Val Precision: 0.5405
# Epoch [156/3000], Train Loss: 0.6707, Train Accuracy: 0.5762, Train AUC: 0.5790, Train Precision: 0.6113, Val Accuracy: 0.5338, Val AUC: 0.5305, Val Precision: 0.5487
# Epoch [157/3000], Train Loss: 0.6706, Train Accuracy: 0.5585, Train AUC: 0.5610, Train Precision: 0.5896, Val Accuracy: 0.5266, Val AUC: 0.5233, Val Precision: 0.5351
# Epoch [158/3000], Train Loss: 0.6708, Train Accuracy: 0.5709, Train AUC: 0.5735, Train Precision: 0.6040, Val Accuracy: 0.5314, Val AUC: 0.5279, Val Precision: 0.5463
# Epoch [159/3000], Train Loss: 0.6688, Train Accuracy: 0.5718, Train AUC: 0.5746, Train Precision: 0.6065, Val Accuracy: 0.5459, Val AUC: 0.5431, Val Precision: 0.5635
# Epoch [160/3000], Train Loss: 0.6694, Train Accuracy: 0.5754, Train AUC: 0.5779, Train Precision: 0.6088, Val Accuracy: 0.5338, Val AUC: 0.5308, Val Precision: 0.5455
# Epoch [161/3000], Train Loss: 0.6714, Train Accuracy: 0.5674, Train AUC: 0.5701, Train Precision: 0.6008, Val Accuracy: 0.5362, Val AUC: 0.5329, Val Precision: 0.5536
# Epoch [162/3000], Train Loss: 0.6682, Train Accuracy: 0.5621, Train AUC: 0.5644, Train Precision: 0.5933, Val Accuracy: 0.5386, Val AUC: 0.5354, Val Precision: 0.5565
# Epoch [163/3000], Train Loss: 0.6713, Train Accuracy: 0.5691, Train AUC: 0.5719, Train Precision: 0.6032, Val Accuracy: 0.5459, Val AUC: 0.5432, Val Precision: 0.5615
# Epoch [164/3000], Train Loss: 0.6616, Train Accuracy: 0.5780, Train AUC: 0.5809, Train Precision: 0.6138, Val Accuracy: 0.5435, Val AUC: 0.5403, Val Precision: 0.5641
# Epoch [165/3000], Train Loss: 0.6661, Train Accuracy: 0.5700, Train AUC: 0.5728, Train Precision: 0.6040, Val Accuracy: 0.5435, Val AUC: 0.5406, Val Precision: 0.5600
# Epoch [166/3000], Train Loss: 0.6715, Train Accuracy: 0.5629, Train AUC: 0.5654, Train Precision: 0.5948, Val Accuracy: 0.5242, Val AUC: 0.5210, Val Precision: 0.5299
# Epoch [167/3000], Train Loss: 0.6698, Train Accuracy: 0.5771, Train AUC: 0.5801, Train Precision: 0.6135, Val Accuracy: 0.5411, Val AUC: 0.5379, Val Precision: 0.5603
# Epoch [168/3000], Train Loss: 0.6679, Train Accuracy: 0.5780, Train AUC: 0.5813, Train Precision: 0.6162, Val Accuracy: 0.5411, Val AUC: 0.5380, Val Precision: 0.5593
# Epoch [169/3000], Train Loss: 0.6697, Train Accuracy: 0.5709, Train AUC: 0.5735, Train Precision: 0.6044, Val Accuracy: 0.5386, Val AUC: 0.5356, Val Precision: 0.5537
# Epoch [170/3000], Train Loss: 0.6668, Train Accuracy: 0.5780, Train AUC: 0.5806, Train Precision: 0.6120, Val Accuracy: 0.5483, Val AUC: 0.5454, Val Precision: 0.5691
# Epoch [171/3000], Train Loss: 0.6696, Train Accuracy: 0.5718, Train AUC: 0.5741, Train Precision: 0.6036, Val Accuracy: 0.5604, Val AUC: 0.5577, Val Precision: 0.5846
# Epoch [172/3000], Train Loss: 0.6670, Train Accuracy: 0.5798, Train AUC: 0.5825, Train Precision: 0.6149, Val Accuracy: 0.5531, Val AUC: 0.5498, Val Precision: 0.5856
# Epoch [173/3000], Train Loss: 0.6710, Train Accuracy: 0.5754, Train AUC: 0.5777, Train Precision: 0.6079, Val Accuracy: 0.5362, Val AUC: 0.5333, Val Precision: 0.5492
# Epoch [174/3000], Train Loss: 0.6705, Train Accuracy: 0.5869, Train AUC: 0.5898, Train Precision: 0.6240, Val Accuracy: 0.5411, Val AUC: 0.5383, Val Precision: 0.5547
# Epoch [175/3000], Train Loss: 0.6688, Train Accuracy: 0.5709, Train AUC: 0.5740, Train Precision: 0.6070, Val Accuracy: 0.5386, Val AUC: 0.5355, Val Precision: 0.5556
# Epoch [176/3000], Train Loss: 0.6714, Train Accuracy: 0.5683, Train AUC: 0.5708, Train Precision: 0.6008, Val Accuracy: 0.5459, Val AUC: 0.5426, Val Precision: 0.5702
# Epoch [177/3000], Train Loss: 0.6687, Train Accuracy: 0.5736, Train AUC: 0.5762, Train Precision: 0.6072, Val Accuracy: 0.5411, Val AUC: 0.5380, Val Precision: 0.5593
# Epoch [178/3000], Train Loss: 0.6708, Train Accuracy: 0.5736, Train AUC: 0.5765, Train Precision: 0.6090, Val Accuracy: 0.5411, Val AUC: 0.5379, Val Precision: 0.5603
# Epoch [179/3000], Train Loss: 0.6696, Train Accuracy: 0.5754, Train AUC: 0.5785, Train Precision: 0.6124, Val Accuracy: 0.5411, Val AUC: 0.5378, Val Precision: 0.5614
# Epoch [180/3000], Train Loss: 0.6644, Train Accuracy: 0.5736, Train AUC: 0.5765, Train Precision: 0.6094, Val Accuracy: 0.5435, Val AUC: 0.5405, Val Precision: 0.5620
# Epoch [181/3000], Train Loss: 0.6672, Train Accuracy: 0.5718, Train AUC: 0.5747, Train Precision: 0.6069, Val Accuracy: 0.5676, Val AUC: 0.5651, Val Precision: 0.5940
# New best model saved with AUC: 0.5651
# Epoch [182/3000], Train Loss: 0.6656, Train Accuracy: 0.5718, Train AUC: 0.5749, Train Precision: 0.6082, Val Accuracy: 0.5483, Val AUC: 0.5453, Val Precision: 0.5702
# Epoch [183/3000], Train Loss: 0.6697, Train Accuracy: 0.5700, Train AUC: 0.5722, Train Precision: 0.6012, Val Accuracy: 0.5531, Val AUC: 0.5499, Val Precision: 0.5826
# Epoch [184/3000], Train Loss: 0.6697, Train Accuracy: 0.5718, Train AUC: 0.5740, Train Precision: 0.6031, Val Accuracy: 0.5507, Val AUC: 0.5478, Val Precision: 0.5726
# Epoch [185/3000], Train Loss: 0.6706, Train Accuracy: 0.5745, Train AUC: 0.5772, Train Precision: 0.6093, Val Accuracy: 0.5435, Val AUC: 0.5406, Val Precision: 0.5600
# Epoch [186/3000], Train Loss: 0.6657, Train Accuracy: 0.5683, Train AUC: 0.5711, Train Precision: 0.6024, Val Accuracy: 0.5483, Val AUC: 0.5455, Val Precision: 0.5669
# Epoch [187/3000], Train Loss: 0.6682, Train Accuracy: 0.5691, Train AUC: 0.5721, Train Precision: 0.6041, Val Accuracy: 0.5386, Val AUC: 0.5356, Val Precision: 0.5546
# Epoch [188/3000], Train Loss: 0.6695, Train Accuracy: 0.5718, Train AUC: 0.5741, Train Precision: 0.6036, Val Accuracy: 0.5459, Val AUC: 0.5430, Val Precision: 0.5645
# Epoch [189/3000], Train Loss: 0.6711, Train Accuracy: 0.5665, Train AUC: 0.5690, Train Precision: 0.5988, Val Accuracy: 0.5362, Val AUC: 0.5332, Val Precision: 0.5500
# Epoch [190/3000], Train Loss: 0.6715, Train Accuracy: 0.5754, Train AUC: 0.5782, Train Precision: 0.6105, Val Accuracy: 0.5338, Val AUC: 0.5305, Val Precision: 0.5495
# Epoch [191/3000], Train Loss: 0.6716, Train Accuracy: 0.5798, Train AUC: 0.5827, Train Precision: 0.6159, Val Accuracy: 0.5435, Val AUC: 0.5408, Val Precision: 0.5581
# Epoch [192/3000], Train Loss: 0.6659, Train Accuracy: 0.5736, Train AUC: 0.5762, Train Precision: 0.6076, Val Accuracy: 0.5483, Val AUC: 0.5453, Val Precision: 0.5702
# Epoch [193/3000], Train Loss: 0.6709, Train Accuracy: 0.5798, Train AUC: 0.5826, Train Precision: 0.6154, Val Accuracy: 0.5507, Val AUC: 0.5477, Val Precision: 0.5750
# Epoch [194/3000], Train Loss: 0.6684, Train Accuracy: 0.5754, Train AUC: 0.5781, Train Precision: 0.6101, Val Accuracy: 0.5362, Val AUC: 0.5334, Val Precision: 0.5476
# Epoch [195/3000], Train Loss: 0.6688, Train Accuracy: 0.5709, Train AUC: 0.5735, Train Precision: 0.6040, Val Accuracy: 0.5338, Val AUC: 0.5305, Val Precision: 0.5495
# Epoch [196/3000], Train Loss: 0.6653, Train Accuracy: 0.5816, Train AUC: 0.5846, Train Precision: 0.6189, Val Accuracy: 0.5411, Val AUC: 0.5382, Val Precision: 0.5556
# Epoch [197/3000], Train Loss: 0.6673, Train Accuracy: 0.5736, Train AUC: 0.5759, Train Precision: 0.6059, Val Accuracy: 0.5435, Val AUC: 0.5404, Val Precision: 0.5630
# Epoch [198/3000], Train Loss: 0.6681, Train Accuracy: 0.5745, Train AUC: 0.5770, Train Precision: 0.6080, Val Accuracy: 0.5411, Val AUC: 0.5378, Val Precision: 0.5614
# Epoch [199/3000], Train Loss: 0.6684, Train Accuracy: 0.5762, Train AUC: 0.5793, Train Precision: 0.6127, Val Accuracy: 0.5580, Val AUC: 0.5550, Val Precision: 0.5854
# Epoch [200/3000], Train Loss: 0.6716, Train Accuracy: 0.5691, Train AUC: 0.5723, Train Precision: 0.6054, Val Accuracy: 0.5362, Val AUC: 0.5331, Val Precision: 0.5517
# Epoch [201/3000], Train Loss: 0.6688, Train Accuracy: 0.5780, Train AUC: 0.5804, Train Precision: 0.6111, Val Accuracy: 0.5386, Val AUC: 0.5358, Val Precision: 0.5520
# Epoch [202/3000], Train Loss: 0.6679, Train Accuracy: 0.5762, Train AUC: 0.5799, Train Precision: 0.6165, Val Accuracy: 0.5556, Val AUC: 0.5527, Val Precision: 0.5806
# Epoch [203/3000], Train Loss: 0.6691, Train Accuracy: 0.5807, Train AUC: 0.5840, Train Precision: 0.6195, Val Accuracy: 0.5362, Val AUC: 0.5331, Val Precision: 0.5517
# Epoch [204/3000], Train Loss: 0.6719, Train Accuracy: 0.5656, Train AUC: 0.5684, Train Precision: 0.5992, Val Accuracy: 0.5362, Val AUC: 0.5328, Val Precision: 0.5545
# Epoch [205/3000], Train Loss: 0.6673, Train Accuracy: 0.5727, Train AUC: 0.5754, Train Precision: 0.6069, Val Accuracy: 0.5386, Val AUC: 0.5354, Val Precision: 0.5575
# Epoch [206/3000], Train Loss: 0.6657, Train Accuracy: 0.5851, Train AUC: 0.5878, Train Precision: 0.6210, Val Accuracy: 0.5483, Val AUC: 0.5453, Val Precision: 0.5702
# Epoch [207/3000], Train Loss: 0.6655, Train Accuracy: 0.5762, Train AUC: 0.5791, Train Precision: 0.6118, Val Accuracy: 0.5435, Val AUC: 0.5406, Val Precision: 0.5600
# Epoch [208/3000], Train Loss: 0.6686, Train Accuracy: 0.5656, Train AUC: 0.5683, Train Precision: 0.5988, Val Accuracy: 0.5290, Val AUC: 0.5260, Val Precision: 0.5372
# Epoch [209/3000], Train Loss: 0.6720, Train Accuracy: 0.5736, Train AUC: 0.5762, Train Precision: 0.6072, Val Accuracy: 0.5435, Val AUC: 0.5405, Val Precision: 0.5620
# Epoch [210/3000], Train Loss: 0.6640, Train Accuracy: 0.5904, Train AUC: 0.5931, Train Precision: 0.6265, Val Accuracy: 0.5507, Val AUC: 0.5476, Val Precision: 0.5763
# Epoch [211/3000], Train Loss: 0.6728, Train Accuracy: 0.5629, Train AUC: 0.5658, Train Precision: 0.5967, Val Accuracy: 0.5338, Val AUC: 0.5306, Val Precision: 0.5478
# Epoch [212/3000], Train Loss: 0.6690, Train Accuracy: 0.5638, Train AUC: 0.5665, Train Precision: 0.5968, Val Accuracy: 0.5483, Val AUC: 0.5454, Val Precision: 0.5691
# Epoch [213/3000], Train Loss: 0.6664, Train Accuracy: 0.5691, Train AUC: 0.5716, Train Precision: 0.6016, Val Accuracy: 0.5048, Val AUC: 0.5022, Val Precision: 0.4962
# Epoch [214/3000], Train Loss: 0.6692, Train Accuracy: 0.5727, Train AUC: 0.5754, Train Precision: 0.6069, Val Accuracy: 0.5338, Val AUC: 0.5307, Val Precision: 0.5462
# Epoch [215/3000], Train Loss: 0.6671, Train Accuracy: 0.5798, Train AUC: 0.5830, Train Precision: 0.6183, Val Accuracy: 0.5097, Val AUC: 0.5068, Val Precision: 0.5040
# Epoch [216/3000], Train Loss: 0.6706, Train Accuracy: 0.5691, Train AUC: 0.5718, Train Precision: 0.6024, Val Accuracy: 0.4541, Val AUC: 0.4520, Val Precision: 0.4257
# Epoch [217/3000], Train Loss: 0.6679, Train Accuracy: 0.5674, Train AUC: 0.5699, Train Precision: 0.6000, Val Accuracy: 0.5411, Val AUC: 0.5380, Val Precision: 0.5593
# Epoch [218/3000], Train Loss: 0.6662, Train Accuracy: 0.5833, Train AUC: 0.5861, Train Precision: 0.6194, Val Accuracy: 0.5483, Val AUC: 0.5457, Val Precision: 0.5649
# Epoch [219/3000], Train Loss: 0.6706, Train Accuracy: 0.5656, Train AUC: 0.5687, Train Precision: 0.6008, Val Accuracy: 0.5362, Val AUC: 0.5335, Val Precision: 0.5469
# Epoch [220/3000], Train Loss: 0.6651, Train Accuracy: 0.5754, Train AUC: 0.5779, Train Precision: 0.6088, Val Accuracy: 0.5411, Val AUC: 0.5385, Val Precision: 0.5522
# Epoch [221/3000], Train Loss: 0.6702, Train Accuracy: 0.5621, Train AUC: 0.5652, Train Precision: 0.5971, Val Accuracy: 0.5338, Val AUC: 0.5309, Val Precision: 0.5447
# Epoch [222/3000], Train Loss: 0.6682, Train Accuracy: 0.5762, Train AUC: 0.5789, Train Precision: 0.6104, Val Accuracy: 0.5362, Val AUC: 0.5331, Val Precision: 0.5508
# Epoch [223/3000], Train Loss: 0.6681, Train Accuracy: 0.5789, Train AUC: 0.5817, Train Precision: 0.6141, Val Accuracy: 0.5386, Val AUC: 0.5358, Val Precision: 0.5520
# Epoch [224/3000], Train Loss: 0.6644, Train Accuracy: 0.5736, Train AUC: 0.5765, Train Precision: 0.6094, Val Accuracy: 0.5483, Val AUC: 0.5452, Val Precision: 0.5714
# Epoch [225/3000], Train Loss: 0.6683, Train Accuracy: 0.5718, Train AUC: 0.5748, Train Precision: 0.6078, Val Accuracy: 0.5411, Val AUC: 0.5380, Val Precision: 0.5583
# Epoch [226/3000], Train Loss: 0.6677, Train Accuracy: 0.5691, Train AUC: 0.5721, Train Precision: 0.6041, Val Accuracy: 0.5435, Val AUC: 0.5402, Val Precision: 0.5664
# Epoch [227/3000], Train Loss: 0.6691, Train Accuracy: 0.5824, Train AUC: 0.5854, Train Precision: 0.6196, Val Accuracy: 0.5314, Val AUC: 0.5287, Val Precision: 0.5385
# Epoch [228/3000], Train Loss: 0.6674, Train Accuracy: 0.5718, Train AUC: 0.5744, Train Precision: 0.6052, Val Accuracy: 0.5411, Val AUC: 0.5380, Val Precision: 0.5593
# Epoch [229/3000], Train Loss: 0.6703, Train Accuracy: 0.5736, Train AUC: 0.5765, Train Precision: 0.6090, Val Accuracy: 0.5386, Val AUC: 0.5356, Val Precision: 0.5537
# Epoch [230/3000], Train Loss: 0.6679, Train Accuracy: 0.5691, Train AUC: 0.5718, Train Precision: 0.6028, Val Accuracy: 0.5483, Val AUC: 0.5452, Val Precision: 0.5726
# Epoch [231/3000], Train Loss: 0.6673, Train Accuracy: 0.5789, Train AUC: 0.5819, Train Precision: 0.6155, Val Accuracy: 0.5097, Val AUC: 0.5065, Val Precision: 0.5043
# Epoch [232/3000], Train Loss: 0.6679, Train Accuracy: 0.5771, Train AUC: 0.5800, Train Precision: 0.6130, Val Accuracy: 0.5507, Val AUC: 0.5478, Val Precision: 0.5726
# Epoch [233/3000], Train Loss: 0.6655, Train Accuracy: 0.5736, Train AUC: 0.5763, Train Precision: 0.6081, Val Accuracy: 0.5386, Val AUC: 0.5356, Val Precision: 0.5546
# Epoch [234/3000], Train Loss: 0.6646, Train Accuracy: 0.5931, Train AUC: 0.5958, Train Precision: 0.6298, Val Accuracy: 0.5386, Val AUC: 0.5357, Val Precision: 0.5528
# Epoch [235/3000], Train Loss: 0.6668, Train Accuracy: 0.5789, Train AUC: 0.5820, Train Precision: 0.6160, Val Accuracy: 0.5217, Val AUC: 0.5189, Val Precision: 0.5238
# Epoch [236/3000], Train Loss: 0.6719, Train Accuracy: 0.5683, Train AUC: 0.5710, Train Precision: 0.6020, Val Accuracy: 0.5193, Val AUC: 0.5165, Val Precision: 0.5200
# Epoch [237/3000], Train Loss: 0.6659, Train Accuracy: 0.5833, Train AUC: 0.5860, Train Precision: 0.6185, Val Accuracy: 0.5242, Val AUC: 0.5214, Val Precision: 0.5276
# Epoch [238/3000], Train Loss: 0.6719, Train Accuracy: 0.5727, Train AUC: 0.5751, Train Precision: 0.6052, Val Accuracy: 0.5314, Val AUC: 0.5279, Val Precision: 0.5463
# Epoch [239/3000], Train Loss: 0.6745, Train Accuracy: 0.5647, Train AUC: 0.5677, Train Precision: 0.5996, Val Accuracy: 0.5459, Val AUC: 0.5431, Val Precision: 0.5635
# Epoch [240/3000], Train Loss: 0.6681, Train Accuracy: 0.5816, Train AUC: 0.5845, Train Precision: 0.6184, Val Accuracy: 0.5459, Val AUC: 0.5429, Val Precision: 0.5667
# Epoch [241/3000], Train Loss: 0.6739, Train Accuracy: 0.5683, Train AUC: 0.5711, Train Precision: 0.6029, Val Accuracy: 0.5531, Val AUC: 0.5503, Val Precision: 0.5760
# Epoch [242/3000], Train Loss: 0.6648, Train Accuracy: 0.5647, Train AUC: 0.5676, Train Precision: 0.5988, Val Accuracy: 0.5362, Val AUC: 0.5331, Val Precision: 0.5517
# Epoch [243/3000], Train Loss: 0.6653, Train Accuracy: 0.5727, Train AUC: 0.5755, Train Precision: 0.6077, Val Accuracy: 0.5411, Val AUC: 0.5382, Val Precision: 0.5565
# Epoch [244/3000], Train Loss: 0.6624, Train Accuracy: 0.5860, Train AUC: 0.5889, Train Precision: 0.6232, Val Accuracy: 0.5435, Val AUC: 0.5407, Val Precision: 0.5591
# Epoch [245/3000], Train Loss: 0.6723, Train Accuracy: 0.5718, Train AUC: 0.5755, Train Precision: 0.6119, Val Accuracy: 0.5169, Val AUC: 0.5142, Val Precision: 0.5154
# Epoch [246/3000], Train Loss: 0.6699, Train Accuracy: 0.5700, Train AUC: 0.5725, Train Precision: 0.6024, Val Accuracy: 0.5435, Val AUC: 0.5406, Val Precision: 0.5600
# Epoch [247/3000], Train Loss: 0.6704, Train Accuracy: 0.5771, Train AUC: 0.5803, Train Precision: 0.6144, Val Accuracy: 0.5290, Val AUC: 0.5260, Val Precision: 0.5372
# Epoch [248/3000], Train Loss: 0.6690, Train Accuracy: 0.5816, Train AUC: 0.5844, Train Precision: 0.6174, Val Accuracy: 0.5507, Val AUC: 0.5478, Val Precision: 0.5738
# Epoch [249/3000], Train Loss: 0.6696, Train Accuracy: 0.5762, Train AUC: 0.5795, Train Precision: 0.6141, Val Accuracy: 0.5411, Val AUC: 0.5378, Val Precision: 0.5614
# Epoch [250/3000], Train Loss: 0.6700, Train Accuracy: 0.5665, Train AUC: 0.5694, Train Precision: 0.6008, Val Accuracy: 0.5386, Val AUC: 0.5358, Val Precision: 0.5520
# Epoch [251/3000], Train Loss: 0.6686, Train Accuracy: 0.5762, Train AUC: 0.5793, Train Precision: 0.6127, Val Accuracy: 0.5435, Val AUC: 0.5410, Val Precision: 0.5547
# Epoch [252/3000], Train Loss: 0.6736, Train Accuracy: 0.5638, Train AUC: 0.5671, Train Precision: 0.6000, Val Accuracy: 0.5338, Val AUC: 0.5305, Val Precision: 0.5495
# Epoch [253/3000], Train Loss: 0.6685, Train Accuracy: 0.5727, Train AUC: 0.5754, Train Precision: 0.6069, Val Accuracy: 0.5386, Val AUC: 0.5359, Val Precision: 0.5504
# Epoch [254/3000], Train Loss: 0.6687, Train Accuracy: 0.5567, Train AUC: 0.5597, Train Precision: 0.5902, Val Accuracy: 0.5242, Val AUC: 0.5216, Val Precision: 0.5259
# Epoch [255/3000], Train Loss: 0.6709, Train Accuracy: 0.5833, Train AUC: 0.5859, Train Precision: 0.6180, Val Accuracy: 0.5435, Val AUC: 0.5405, Val Precision: 0.5620
# Epoch [256/3000], Train Loss: 0.6658, Train Accuracy: 0.5736, Train AUC: 0.5765, Train Precision: 0.6090, Val Accuracy: 0.5386, Val AUC: 0.5355, Val Precision: 0.5556
# Epoch [257/3000], Train Loss: 0.6779, Train Accuracy: 0.5665, Train AUC: 0.5697, Train Precision: 0.6025, Val Accuracy: 0.5435, Val AUC: 0.5405, Val Precision: 0.5620
# Epoch [258/3000], Train Loss: 0.6745, Train Accuracy: 0.5434, Train AUC: 0.5460, Train Precision: 0.5731, Val Accuracy: 0.5459, Val AUC: 0.5433, Val Precision: 0.5606
# Epoch [259/3000], Train Loss: 0.6708, Train Accuracy: 0.5798, Train AUC: 0.5827, Train Precision: 0.6159, Val Accuracy: 0.5193, Val AUC: 0.5168, Val Precision: 0.5185
# Epoch [260/3000], Train Loss: 0.6676, Train Accuracy: 0.5709, Train AUC: 0.5740, Train Precision: 0.6070, Val Accuracy: 0.5121, Val AUC: 0.5096, Val Precision: 0.5074
# Epoch [261/3000], Train Loss: 0.6661, Train Accuracy: 0.5798, Train AUC: 0.5830, Train Precision: 0.6178, Val Accuracy: 0.5314, Val AUC: 0.5289, Val Precision: 0.5368
# Epoch [262/3000], Train Loss: 0.6688, Train Accuracy: 0.5913, Train AUC: 0.5943, Train Precision: 0.6299, Val Accuracy: 0.5145, Val AUC: 0.5115, Val Precision: 0.5124
# Epoch [263/3000], Train Loss: 0.6663, Train Accuracy: 0.5878, Train AUC: 0.5905, Train Precision: 0.6242, Val Accuracy: 0.5459, Val AUC: 0.5430, Val Precision: 0.5645
# Epoch [264/3000], Train Loss: 0.6662, Train Accuracy: 0.5798, Train AUC: 0.5831, Train Precision: 0.6188, Val Accuracy: 0.5386, Val AUC: 0.5353, Val Precision: 0.5586
# Epoch [265/3000], Train Loss: 0.6676, Train Accuracy: 0.5674, Train AUC: 0.5702, Train Precision: 0.6016, Val Accuracy: 0.5290, Val AUC: 0.5261, Val Precision: 0.5360
# Epoch [266/3000], Train Loss: 0.6654, Train Accuracy: 0.5771, Train AUC: 0.5800, Train Precision: 0.6126, Val Accuracy: 0.5459, Val AUC: 0.5429, Val Precision: 0.5656
# Epoch [267/3000], Train Loss: 0.6676, Train Accuracy: 0.5816, Train AUC: 0.5847, Train Precision: 0.6193, Val Accuracy: 0.5411, Val AUC: 0.5377, Val Precision: 0.5625
# Epoch [268/3000], Train Loss: 0.6676, Train Accuracy: 0.5789, Train AUC: 0.5823, Train Precision: 0.6184, Val Accuracy: 0.5411, Val AUC: 0.5380, Val Precision: 0.5583
# Epoch [269/3000], Train Loss: 0.6670, Train Accuracy: 0.5816, Train AUC: 0.5850, Train Precision: 0.6213, Val Accuracy: 0.5411, Val AUC: 0.5382, Val Precision: 0.5565
# Epoch [270/3000], Train Loss: 0.6674, Train Accuracy: 0.5754, Train AUC: 0.5789, Train Precision: 0.6152, Val Accuracy: 0.5290, Val AUC: 0.5259, Val Precision: 0.5378
# Epoch [271/3000], Train Loss: 0.6700, Train Accuracy: 0.5550, Train AUC: 0.5580, Train Precision: 0.5885, Val Accuracy: 0.5145, Val AUC: 0.5118, Val Precision: 0.5116
# Epoch [272/3000], Train Loss: 0.6673, Train Accuracy: 0.5727, Train AUC: 0.5754, Train Precision: 0.6069, Val Accuracy: 0.5459, Val AUC: 0.5430, Val Precision: 0.5645
# Epoch [273/3000], Train Loss: 0.6737, Train Accuracy: 0.5567, Train AUC: 0.5594, Train Precision: 0.5887, Val Accuracy: 0.5386, Val AUC: 0.5355, Val Precision: 0.5556
# Epoch [274/3000], Train Loss: 0.6683, Train Accuracy: 0.5798, Train AUC: 0.5829, Train Precision: 0.6173, Val Accuracy: 0.5242, Val AUC: 0.5218, Val Precision: 0.5252
# Epoch [275/3000], Train Loss: 0.6691, Train Accuracy: 0.5718, Train AUC: 0.5745, Train Precision: 0.6061, Val Accuracy: 0.5411, Val AUC: 0.5381, Val Precision: 0.5574
# Epoch [276/3000], Train Loss: 0.6666, Train Accuracy: 0.5789, Train AUC: 0.5820, Train Precision: 0.6165, Val Accuracy: 0.5024, Val AUC: 0.5001, Val Precision: 0.4930
# Epoch [277/3000], Train Loss: 0.6720, Train Accuracy: 0.5621, Train AUC: 0.5651, Train Precision: 0.5967, Val Accuracy: 0.5145, Val AUC: 0.5118, Val Precision: 0.5115
# Epoch [278/3000], Train Loss: 0.6677, Train Accuracy: 0.5727, Train AUC: 0.5755, Train Precision: 0.6077, Val Accuracy: 0.5290, Val AUC: 0.5261, Val Precision: 0.5360
# Epoch [279/3000], Train Loss: 0.6668, Train Accuracy: 0.5727, Train AUC: 0.5752, Train Precision: 0.6060, Val Accuracy: 0.5169, Val AUC: 0.5140, Val Precision: 0.5161
# Epoch [280/3000], Train Loss: 0.6715, Train Accuracy: 0.5771, Train AUC: 0.5801, Train Precision: 0.6135, Val Accuracy: 0.5242, Val AUC: 0.5219, Val Precision: 0.5245
# Epoch [281/3000], Train Loss: 0.6666, Train Accuracy: 0.5762, Train AUC: 0.5793, Train Precision: 0.6132, Val Accuracy: 0.5193, Val AUC: 0.5164, Val Precision: 0.5203
# Epoch [282/3000], Train Loss: 0.6691, Train Accuracy: 0.5798, Train AUC: 0.5821, Train Precision: 0.6126, Val Accuracy: 0.5266, Val AUC: 0.5239, Val Precision: 0.5303
# Epoch [283/3000], Train Loss: 0.6690, Train Accuracy: 0.5727, Train AUC: 0.5755, Train Precision: 0.6073, Val Accuracy: 0.5338, Val AUC: 0.5314, Val Precision: 0.5401
# Epoch [284/3000], Train Loss: 0.6650, Train Accuracy: 0.5771, Train AUC: 0.5804, Train Precision: 0.6154, Val Accuracy: 0.5362, Val AUC: 0.5335, Val Precision: 0.5462
# Epoch [285/3000], Train Loss: 0.6651, Train Accuracy: 0.5683, Train AUC: 0.5708, Train Precision: 0.6012, Val Accuracy: 0.5217, Val AUC: 0.5191, Val Precision: 0.5227
# Epoch [286/3000], Train Loss: 0.6676, Train Accuracy: 0.5824, Train AUC: 0.5849, Train Precision: 0.6163, Val Accuracy: 0.5169, Val AUC: 0.5146, Val Precision: 0.5143
# ...
# Epoch [1725/3000], Train Loss: 0.6563, Train Accuracy: 0.6152, Train AUC: 0.6173, Train Precision: 0.6498, Val Accuracy: 0.5338, Val AUC: 0.5319, Val Precision: 0.5364
# Epoch [1726/3000], Train Loss: 0.6583, Train Accuracy: 0.6223, Train AUC: 0.6242, Train Precision: 0.6558, Val Accuracy: 0.5121, Val AUC: 0.5102, Val Precision: 0.5066
# Epoch [1727/3000], Train Loss: 0.6596, Train Accuracy: 0.6152, Train AUC: 0.6166, Train Precision: 0.6442, Val Accuracy: 0.5531, Val AUC: 0.5508, Val Precision: 0.5683
# Epoch [1728/3000], Train Loss: 0.6601, Train Accuracy: 0.6020, Train AUC: 0.6041, Train Precision: 0.6355, Val Accuracy: 0.5459, Val AUC: 0.5434, Val Precision: 0.5588
# Epoch [1729/3000], Train Loss: 0.6635, Train Accuracy: 0.5993, Train AUC: 0.6013, Train Precision: 0.6318, Val Accuracy: 0.5314, Val AUC: 0.5294, Val Precision: 0.5333
# Epoch [1730/3000], Train Loss: 0.6526, Train Accuracy: 0.6108, Train AUC: 0.6126, Train Precision: 0.6424, Val Accuracy: 0.5242, Val AUC: 0.5223, Val Precision: 0.5229
# Epoch [1731/3000], Train Loss: 0.6618, Train Accuracy: 0.6294, Train AUC: 0.6317, Train Precision: 0.6667, Val Accuracy: 0.5556, Val AUC: 0.5531, Val Precision: 0.5735
# Epoch [1732/3000], Train Loss: 0.6601, Train Accuracy: 0.6037, Train AUC: 0.6065, Train Precision: 0.6424, Val Accuracy: 0.5242, Val AUC: 0.5221, Val Precision: 0.5238
# Epoch [1733/3000], Train Loss: 0.6584, Train Accuracy: 0.6108, Train AUC: 0.6125, Train Precision: 0.6419, Val Accuracy: 0.5193, Val AUC: 0.5175, Val Precision: 0.5161
# Epoch [1734/3000], Train Loss: 0.6588, Train Accuracy: 0.6108, Train AUC: 0.6126, Train Precision: 0.6430, Val Accuracy: 0.5000, Val AUC: 0.4988, Val Precision: 0.4913
# Epoch [1735/3000], Train Loss: 0.6606, Train Accuracy: 0.6082, Train AUC: 0.6098, Train Precision: 0.6388, Val Accuracy: 0.5072, Val AUC: 0.5050, Val Precision: 0.5000
# Epoch [1736/3000], Train Loss: 0.6558, Train Accuracy: 0.6161, Train AUC: 0.6183, Train Precision: 0.6511, Val Accuracy: 0.5000, Val AUC: 0.4980, Val Precision: 0.4901
# Epoch [1737/3000], Train Loss: 0.6597, Train Accuracy: 0.6090, Train AUC: 0.6106, Train Precision: 0.6389, Val Accuracy: 0.4976, Val AUC: 0.4959, Val Precision: 0.4873
# Epoch [1738/3000], Train Loss: 0.6602, Train Accuracy: 0.6117, Train AUC: 0.6136, Train Precision: 0.6448, Val Accuracy: 0.5459, Val AUC: 0.5440, Val Precision: 0.5526
# Epoch [1739/3000], Train Loss: 0.6607, Train Accuracy: 0.5984, Train AUC: 0.6004, Train Precision: 0.6311, Val Accuracy: 0.4807, Val AUC: 0.4798, Val Precision: 0.4699
# Epoch [1740/3000], Train Loss: 0.6547, Train Accuracy: 0.6188, Train AUC: 0.6204, Train Precision: 0.6496, Val Accuracy: 0.5459, Val AUC: 0.5442, Val Precision: 0.5506
# Epoch [1741/3000], Train Loss: 0.6600, Train Accuracy: 0.6082, Train AUC: 0.6097, Train Precision: 0.6383, Val Accuracy: 0.5072, Val AUC: 0.5057, Val Precision: 0.5000
# Epoch [1742/3000], Train Loss: 0.6591, Train Accuracy: 0.6002, Train AUC: 0.6011, Train Precision: 0.6257, Val Accuracy: 0.5242, Val AUC: 0.5228, Val Precision: 0.5210
# Epoch [1743/3000], Train Loss: 0.6623, Train Accuracy: 0.6135, Train AUC: 0.6152, Train Precision: 0.6450, Val Accuracy: 0.5459, Val AUC: 0.5443, Val Precision: 0.5494
# Epoch [1744/3000], Train Loss: 0.6565, Train Accuracy: 0.6152, Train AUC: 0.6164, Train Precision: 0.6426, Val Accuracy: 0.5169, Val AUC: 0.5148, Val Precision: 0.5135
# Epoch [1745/3000], Train Loss: 0.6623, Train Accuracy: 0.6206, Train AUC: 0.6234, Train Precision: 0.6613, Val Accuracy: 0.5435, Val AUC: 0.5412, Val Precision: 0.5524
# Epoch [1746/3000], Train Loss: 0.6629, Train Accuracy: 0.6011, Train AUC: 0.6035, Train Precision: 0.6369, Val Accuracy: 0.5459, Val AUC: 0.5445, Val Precision: 0.5482
# Epoch [1747/3000], Train Loss: 0.6518, Train Accuracy: 0.6206, Train AUC: 0.6220, Train Precision: 0.6504, Val Accuracy: 0.5386, Val AUC: 0.5374, Val Precision: 0.5380
# Epoch [1748/3000], Train Loss: 0.6559, Train Accuracy: 0.6135, Train AUC: 0.6147, Train Precision: 0.6413, Val Accuracy: 0.5338, Val AUC: 0.5316, Val Precision: 0.5385
# Epoch [1749/3000], Train Loss: 0.6573, Train Accuracy: 0.6277, Train AUC: 0.6297, Train Precision: 0.6628, Val Accuracy: 0.5217, Val AUC: 0.5194, Val Precision: 0.5214
# Epoch [1750/3000], Train Loss: 0.6546, Train Accuracy: 0.6285, Train AUC: 0.6303, Train Precision: 0.6610, Val Accuracy: 0.5435, Val AUC: 0.5410, Val Precision: 0.5547
# Epoch [1751/3000], Train Loss: 0.6684, Train Accuracy: 0.6028, Train AUC: 0.6037, Train Precision: 0.6282, Val Accuracy: 0.5338, Val AUC: 0.5320, Val Precision: 0.5355
# Epoch [1752/3000], Train Loss: 0.6621, Train Accuracy: 0.5966, Train AUC: 0.5984, Train Precision: 0.6276, Val Accuracy: 0.5411, Val AUC: 0.5395, Val Precision: 0.5432
# Epoch [1753/3000], Train Loss: 0.6601, Train Accuracy: 0.6020, Train AUC: 0.6036, Train Precision: 0.6324, Val Accuracy: 0.5386, Val AUC: 0.5365, Val Precision: 0.5448
# Epoch [1754/3000], Train Loss: 0.6591, Train Accuracy: 0.6064, Train AUC: 0.6079, Train Precision: 0.6364, Val Accuracy: 0.5217, Val AUC: 0.5202, Val Precision: 0.5185
# Epoch [1755/3000], Train Loss: 0.6566, Train Accuracy: 0.6250, Train AUC: 0.6265, Train Precision: 0.6554, Val Accuracy: 0.5386, Val AUC: 0.5372, Val Precision: 0.5394
# Epoch [1756/3000], Train Loss: 0.6559, Train Accuracy: 0.6259, Train AUC: 0.6272, Train Precision: 0.6554, Val Accuracy: 0.5338, Val AUC: 0.5318, Val Precision: 0.5369
# Epoch [1757/3000], Train Loss: 0.6575, Train Accuracy: 0.6099, Train AUC: 0.6122, Train Precision: 0.6457, Val Accuracy: 0.5169, Val AUC: 0.5155, Val Precision: 0.5120
# Epoch [1758/3000], Train Loss: 0.6602, Train Accuracy: 0.6241, Train AUC: 0.6259, Train Precision: 0.6571, Val Accuracy: 0.5435, Val AUC: 0.5418, Val Precision: 0.5472
# Epoch [1759/3000], Train Loss: 0.6571, Train Accuracy: 0.6126, Train AUC: 0.6144, Train Precision: 0.6449, Val Accuracy: 0.5386, Val AUC: 0.5367, Val Precision: 0.5430
# Epoch [1760/3000], Train Loss: 0.6564, Train Accuracy: 0.6046, Train AUC: 0.6069, Train Precision: 0.6398, Val Accuracy: 0.5193, Val AUC: 0.5169, Val Precision: 0.5182
# Epoch [1761/3000], Train Loss: 0.6611, Train Accuracy: 0.6206, Train AUC: 0.6221, Train Precision: 0.6515, Val Accuracy: 0.5217, Val AUC: 0.5201, Val Precision: 0.5188
# Epoch [1762/3000], Train Loss: 0.6604, Train Accuracy: 0.5922, Train AUC: 0.5945, Train Precision: 0.6260, Val Accuracy: 0.5435, Val AUC: 0.5416, Val Precision: 0.5490
# Epoch [1763/3000], Train Loss: 0.6535, Train Accuracy: 0.6241, Train AUC: 0.6259, Train Precision: 0.6571, Val Accuracy: 0.5048, Val AUC: 0.5040, Val Precision: 0.4973
# Epoch [1764/3000], Train Loss: 0.6551, Train Accuracy: 0.6277, Train AUC: 0.6291, Train Precision: 0.6579, Val Accuracy: 0.5314, Val AUC: 0.5302, Val Precision: 0.5291
# Epoch [1765/3000], Train Loss: 0.6624, Train Accuracy: 0.6152, Train AUC: 0.6173, Train Precision: 0.6498, Val Accuracy: 0.5459, Val AUC: 0.5444, Val Precision: 0.5488
# Epoch [1766/3000], Train Loss: 0.6597, Train Accuracy: 0.6020, Train AUC: 0.6038, Train Precision: 0.6334, Val Accuracy: 0.5338, Val AUC: 0.5314, Val Precision: 0.5401
# Epoch [1767/3000], Train Loss: 0.6579, Train Accuracy: 0.6082, Train AUC: 0.6104, Train Precision: 0.6431, Val Accuracy: 0.5266, Val AUC: 0.5242, Val Precision: 0.5290
# Epoch [1768/3000], Train Loss: 0.6578, Train Accuracy: 0.6046, Train AUC: 0.6067, Train Precision: 0.6381, Val Accuracy: 0.5290, Val AUC: 0.5277, Val Precision: 0.5263
# Epoch [1769/3000], Train Loss: 0.6567, Train Accuracy: 0.6090, Train AUC: 0.6105, Train Precision: 0.6384, Val Accuracy: 0.5459, Val AUC: 0.5440, Val Precision: 0.5519
# Epoch [1770/3000], Train Loss: 0.6588, Train Accuracy: 0.6108, Train AUC: 0.6126, Train Precision: 0.6424, Val Accuracy: 0.5169, Val AUC: 0.5150, Val Precision: 0.5132
# Epoch [1771/3000], Train Loss: 0.6574, Train Accuracy: 0.5993, Train AUC: 0.6011, Train Precision: 0.6308, Val Accuracy: 0.5507, Val AUC: 0.5491, Val Precision: 0.5563
# Epoch [1772/3000], Train Loss: 0.6587, Train Accuracy: 0.6188, Train AUC: 0.6207, Train Precision: 0.6519, Val Accuracy: 0.5435, Val AUC: 0.5418, Val Precision: 0.5472
# Epoch [1773/3000], Train Loss: 0.6524, Train Accuracy: 0.6285, Train AUC: 0.6296, Train Precision: 0.6556, Val Accuracy: 0.5386, Val AUC: 0.5363, Val Precision: 0.5461
# Epoch [1774/3000], Train Loss: 0.6620, Train Accuracy: 0.6055, Train AUC: 0.6073, Train Precision: 0.6372, Val Accuracy: 0.5338, Val AUC: 0.5322, Val Precision: 0.5342
# Epoch [1775/3000], Train Loss: 0.6576, Train Accuracy: 0.6144, Train AUC: 0.6157, Train Precision: 0.6430, Val Accuracy: 0.5362, Val AUC: 0.5346, Val Precision: 0.5375
# Epoch [1776/3000], Train Loss: 0.6640, Train Accuracy: 0.6117, Train AUC: 0.6137, Train Precision: 0.6453, Val Accuracy: 0.5459, Val AUC: 0.5440, Val Precision: 0.5526
# Epoch [1777/3000], Train Loss: 0.6625, Train Accuracy: 0.6064, Train AUC: 0.6077, Train Precision: 0.6348, Val Accuracy: 0.5531, Val AUC: 0.5515, Val Precision: 0.5597
# Epoch [1778/3000], Train Loss: 0.6586, Train Accuracy: 0.6144, Train AUC: 0.6160, Train Precision: 0.6452, Val Accuracy: 0.5386, Val AUC: 0.5366, Val Precision: 0.5436
# Epoch [1779/3000], Train Loss: 0.6540, Train Accuracy: 0.6268, Train AUC: 0.6289, Train Precision: 0.6628, Val Accuracy: 0.5459, Val AUC: 0.5442, Val Precision: 0.5506
# Epoch [1780/3000], Train Loss: 0.6535, Train Accuracy: 0.6135, Train AUC: 0.6155, Train Precision: 0.6473, Val Accuracy: 0.5459, Val AUC: 0.5439, Val Precision: 0.5533
# Epoch [1781/3000], Train Loss: 0.6502, Train Accuracy: 0.6277, Train AUC: 0.6293, Train Precision: 0.6597, Val Accuracy: 0.5290, Val AUC: 0.5269, Val Precision: 0.5306
# Epoch [1782/3000], Train Loss: 0.6544, Train Accuracy: 0.6188, Train AUC: 0.6206, Train Precision: 0.6513, Val Accuracy: 0.5290, Val AUC: 0.5270, Val Precision: 0.5302
# Epoch [1783/3000], Train Loss: 0.6525, Train Accuracy: 0.6215, Train AUC: 0.6235, Train Precision: 0.6557, Val Accuracy: 0.5362, Val AUC: 0.5339, Val Precision: 0.5429
# Epoch [1784/3000], Train Loss: 0.6568, Train Accuracy: 0.6152, Train AUC: 0.6170, Train Precision: 0.6469, Val Accuracy: 0.5169, Val AUC: 0.5149, Val Precision: 0.5133
# Epoch [1785/3000], Train Loss: 0.6559, Train Accuracy: 0.6188, Train AUC: 0.6210, Train Precision: 0.6543, Val Accuracy: 0.5459, Val AUC: 0.5438, Val Precision: 0.5541
# Epoch [1786/3000], Train Loss: 0.6568, Train Accuracy: 0.6082, Train AUC: 0.6099, Train Precision: 0.6393, Val Accuracy: 0.5338, Val AUC: 0.5317, Val Precision: 0.5374
# Epoch [1787/3000], Train Loss: 0.6570, Train Accuracy: 0.6215, Train AUC: 0.6226, Train Precision: 0.6494, Val Accuracy: 0.5507, Val AUC: 0.5489, Val Precision: 0.5584
# Epoch [1788/3000], Train Loss: 0.6535, Train Accuracy: 0.6268, Train AUC: 0.6287, Train Precision: 0.6609, Val Accuracy: 0.5169, Val AUC: 0.5149, Val Precision: 0.5133
# Epoch [1789/3000], Train Loss: 0.6573, Train Accuracy: 0.6126, Train AUC: 0.6143, Train Precision: 0.6444, Val Accuracy: 0.5507, Val AUC: 0.5492, Val Precision: 0.5549
# Epoch [1790/3000], Train Loss: 0.6583, Train Accuracy: 0.6002, Train AUC: 0.6013, Train Precision: 0.6271, Val Accuracy: 0.5362, Val AUC: 0.5349, Val Precision: 0.5353
# Epoch [1791/3000], Train Loss: 0.6494, Train Accuracy: 0.6188, Train AUC: 0.6201, Train Precision: 0.6474, Val Accuracy: 0.5362, Val AUC: 0.5338, Val Precision: 0.5441
# Epoch [1792/3000], Train Loss: 0.6553, Train Accuracy: 0.6161, Train AUC: 0.6177, Train Precision: 0.6465, Val Accuracy: 0.5483, Val AUC: 0.5466, Val Precision: 0.5535
# Epoch [1793/3000], Train Loss: 0.6571, Train Accuracy: 0.6206, Train AUC: 0.6218, Train Precision: 0.6493, Val Accuracy: 0.5507, Val AUC: 0.5488, Val Precision: 0.5592
# Epoch [1794/3000], Train Loss: 0.6602, Train Accuracy: 0.5957, Train AUC: 0.5975, Train Precision: 0.6264, Val Accuracy: 0.5435, Val AUC: 0.5412, Val Precision: 0.5532
# Epoch [1795/3000], Train Loss: 0.6564, Train Accuracy: 0.5966, Train AUC: 0.5981, Train Precision: 0.6252, Val Accuracy: 0.5338, Val AUC: 0.5319, Val Precision: 0.5359
# Epoch [1796/3000], Train Loss: 0.6597, Train Accuracy: 0.6099, Train AUC: 0.6117, Train Precision: 0.6418, Val Accuracy: 0.5459, Val AUC: 0.5435, Val Precision: 0.5580
# Epoch [1797/3000], Train Loss: 0.6594, Train Accuracy: 0.6188, Train AUC: 0.6206, Train Precision: 0.6513, Val Accuracy: 0.5338, Val AUC: 0.5315, Val Precision: 0.5390
# Epoch [1798/3000], Train Loss: 0.6592, Train Accuracy: 0.6037, Train AUC: 0.6058, Train Precision: 0.6374, Val Accuracy: 0.5048, Val AUC: 0.5033, Val Precision: 0.4969
# Epoch [1799/3000], Train Loss: 0.6654, Train Accuracy: 0.6064, Train AUC: 0.6077, Train Precision: 0.6348, Val Accuracy: 0.5048, Val AUC: 0.5029, Val Precision: 0.4967
# Epoch [1800/3000], Train Loss: 0.6575, Train Accuracy: 0.6179, Train AUC: 0.6195, Train Precision: 0.6490, Val Accuracy: 0.5290, Val AUC: 0.5270, Val Precision: 0.5298
# Epoch [1801/3000], Train Loss: 0.6599, Train Accuracy: 0.5957, Train AUC: 0.5973, Train Precision: 0.6250, Val Accuracy: 0.5314, Val AUC: 0.5293, Val Precision: 0.5338
# Epoch [1802/3000], Train Loss: 0.6550, Train Accuracy: 0.6073, Train AUC: 0.6085, Train Precision: 0.6350, Val Accuracy: 0.5338, Val AUC: 0.5317, Val Precision: 0.5374
# Epoch [1803/3000], Train Loss: 0.6617, Train Accuracy: 0.6055, Train AUC: 0.6078, Train Precision: 0.6410, Val Accuracy: 0.5000, Val AUC: 0.4981, Val Precision: 0.4902
# Epoch [1804/3000], Train Loss: 0.6554, Train Accuracy: 0.6028, Train AUC: 0.6037, Train Precision: 0.6282, Val Accuracy: 0.5362, Val AUC: 0.5341, Val Precision: 0.5411
# Epoch [1805/3000], Train Loss: 0.6582, Train Accuracy: 0.6294, Train AUC: 0.6311, Train Precision: 0.6616, Val Accuracy: 0.5411, Val AUC: 0.5394, Val Precision: 0.5443
# Epoch [1806/3000], Train Loss: 0.6557, Train Accuracy: 0.6055, Train AUC: 0.6069, Train Precision: 0.6347, Val Accuracy: 0.5314, Val AUC: 0.5293, Val Precision: 0.5342
# Epoch [1807/3000], Train Loss: 0.6535, Train Accuracy: 0.6135, Train AUC: 0.6160, Train Precision: 0.6514, Val Accuracy: 0.5435, Val AUC: 0.5417, Val Precision: 0.5484
# Epoch [1808/3000], Train Loss: 0.6589, Train Accuracy: 0.6152, Train AUC: 0.6172, Train Precision: 0.6486, Val Accuracy: 0.5314, Val AUC: 0.5289, Val Precision: 0.5368
# Epoch [1809/3000], Train Loss: 0.6598, Train Accuracy: 0.5904, Train AUC: 0.5923, Train Precision: 0.6212, Val Accuracy: 0.5507, Val AUC: 0.5489, Val Precision: 0.5577
# Epoch [1810/3000], Train Loss: 0.6551, Train Accuracy: 0.6170, Train AUC: 0.6197, Train Precision: 0.6566, Val Accuracy: 0.5411, Val AUC: 0.5389, Val Precision: 0.5479
# Epoch [1811/3000], Train Loss: 0.6561, Train Accuracy: 0.6197, Train AUC: 0.6214, Train Precision: 0.6520, Val Accuracy: 0.5435, Val AUC: 0.5412, Val Precision: 0.5532
# Epoch [1812/3000], Train Loss: 0.6639, Train Accuracy: 0.5940, Train AUC: 0.5956, Train Precision: 0.6236, Val Accuracy: 0.5362, Val AUC: 0.5340, Val Precision: 0.5423
# Epoch [1813/3000], Train Loss: 0.6548, Train Accuracy: 0.6215, Train AUC: 0.6230, Train Precision: 0.6522, Val Accuracy: 0.5266, Val AUC: 0.5241, Val Precision: 0.5294
# Epoch [1814/3000], Train Loss: 0.6521, Train Accuracy: 0.6170, Train AUC: 0.6192, Train Precision: 0.6523, Val Accuracy: 0.5338, Val AUC: 0.5316, Val Precision: 0.5385
# Epoch [1815/3000], Train Loss: 0.6624, Train Accuracy: 0.6294, Train AUC: 0.6309, Train Precision: 0.6598, Val Accuracy: 0.5435, Val AUC: 0.5419, Val Precision: 0.5460
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 train_model(train_dataloader, val_dataloader, model, criterion, optimizer, num_epochs=3000)
#
# Cell In[29], line 31, in train_model(train_dataloader, val_dataloader, model, criterion, optimizer, num_epochs)
#      28 loss.backward()
#      29 optimizer.step()
# ---> 31 running_loss += loss.item()
#      32 train_preds.extend(preds.detach().cpu().numpy())
#      33 train_labels.extend(labels.cpu().numpy())
#
# KeyboardInterrupt:
